# %%
import pandas as pd
import os
import requests
from bs4 import BeautifulSoup
import wikipediaapi
import wikipedia
from groq import Groq

attractions = pd.read_csv('sightseeing_places_ISTANBUL.csv')

attractions.head()
# Out:
#                     NAME   LONGITUDE   LATITUDE
# 0         Ayasofya Camii  28.980175   41.008583
# 1  Topkapı Sarayı Müzesi  28.983379    41.01152
# 2      Yerebatan Sarnıcı   28.977878  41.008384
# 3     Sultan Ahmet Camii   28.976814   41.00541
# 4    Sultanahmet Meydanı  28.975705   41.006329

# %%
# Define a User-Agent for your script
USER_AGENT = "MyWikipediaScraper/1.0 (https://example.com; contact@example.com)"

# Initialize Wikipedia API for Turkish and English
wiki_en = wikipediaapi.Wikipedia(
    user_agent=USER_AGENT,
    language='en'
)
wiki_tr = wikipediaapi.Wikipedia(
    user_agent=USER_AGENT,
    language='tr'
)
# Function to find the closest match using Wikipedia search
def get_closest_match(title, lang='en'):
    # Perform a search for the closest match
    wikipedia.set_lang(lang)
    results = wikipedia.search(title, results=1)
    if results:
        return results[0]  # Return the top match
    else:
        return None

# Function to fetch Wikipedia content in English using Turkish input
def fetch_wikipedia_content(place):
    # Step 1: Find the closest match in Turkish Wikipedia
    closest_title_tr = get_closest_match(place, lang='tr')

    if closest_title_tr:  # If a Turkish match is found
        # Fetch Turkish page
        page_tr = wiki_tr.page(closest_title_tr)
        if page_tr.exists():
            # Step 2: Check for English translation in Turkish page
            if 'en' in page_tr.langlinks:
                english_title = page_tr.langlinks['en'].title  # Use the English translation
            else:
                # Step 3: Apply closest match search in English Wikipedia
                english_title = get_closest_match(closest_title_tr, lang='en')

            # Step 4: Fetch English content
            if english_title:
                page_en = wiki_en.page(english_title)

                # If no exact match, apply closest match search again in English
                if not page_en.exists():
                    english_title = get_closest_match(english_title, lang='en')
                    page_en = wiki_en.page(english_title)

                # Return final English title and content
                if page_en.exists():
                    return english_title, page_en.text
                else:
                    return english_title, "No English content found."
            else:
                return "No Match", "No English page found."
        else:
            return "No Match", "No Turkish page found."
    else:
        return "No Match", "No match found."

# Process each place in the dataset
knowledge_data = []
for place in attractions["NAME"]:
    english_title, content = fetch_wikipedia_content(place)
    knowledge_data.append({
        "Place" : english_title,
        "Content": content
    })

# Create a DataFrame for visualization
knowledge_df = pd.DataFrame(knowledge_data)

# Optionally, save to a CSV file
knowledge_df.to_csv("istanbul_places_wikipedia_content.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 63
#      61 knowledge_data = []
#      62 for place in attractions["NAME"]:
# ---> 63     english_title, content = fetch_wikipedia_content(place)
#      64     knowledge_data.append({
#      65         "Place" : english_title,
#      66         "Content": content
#      67     })
#      69 # Create a DataFrame for visualization
#
# Cell In[3], line 33, in fetch_wikipedia_content(place)
#      30 page_tr = wiki_tr.page(closest_title_tr)
#      31 if page_tr.exists():
#      32     # Step 2: Check for English translation in Turkish page
# ---> 33     if 'en' in page_tr.langlinks:
#      34         english_title = page_tr.langlinks['en'].title  # Use the English translation
#      35     else:
#      36         # Step 3: Apply closest match search in English Wikipedia
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/wikipediaapi/__init__.py:996, in WikipediaPage.langlinks(self)
#     985 """
#     986 Returns all language links to pages in other languages.
#     987
#    (...)
#     993 :return: :class:`PagesDict`
#     994 """
#     995 if not self._called["langlinks"]:
# --> 996     self._fetch("langlinks")
#     997 return self._langlinks
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/wikipediaapi/__init__.py:1065, in WikipediaPage._fetch(self, call)
#    1063 def _fetch(self, call) -> "WikipediaPage":
#    1064     """Fetches some data?."""
# -> 1065     getattr(self.wiki, call)(self)
#    1066     self._called[call] = True
#    1067     return self
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/wikipediaapi/__init__.py:369, in Wikipedia.langlinks(self, page, **kwargs)
#     366 used_params = kwargs
#     367 used_params.update(params)
# --> 369 raw = self._query(page, used_params)
#     370 self._common_attributes(raw["query"], page)
#     371 pages = raw["query"]["pages"]
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/wikipediaapi/__init__.py:529, in Wikipedia._query(self, page, params)
#     527 params["format"] = "json"
#     528 params["redirects"] = 1
# --> 529 r = self._session.get(base_url, params=params, **self._request_kwargs)
#     530 return r.json()
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/socket.py:716, in SocketIO.readinto(self, b)
#     714 while True:
#     715     try:
# --> 716         return self._sock.recv_into(b)
#     717     except timeout:
#     718         self._timeout_occurred = True
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/ssl.py:1275, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271     if flags != 0:
#    1272         raise ValueError(
#    1273           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1274           self.__class__)
# -> 1275     return self.read(nbytes, buffer)
#    1276 else:
#    1277     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/ssl.py:1133, in SSLSocket.read(self, len, buffer)
#    1131 try:
#    1132     if buffer is not None:
# -> 1133         return self._sslobj.read(len, buffer)
#    1134     else:
#    1135         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# URL for scraping
from urllib.parse import urljoin
import time
# Base URL for crawling
base_url = "https://muze.gen.tr/Museums"

from openai import OpenAI

# Create OpenAI client
openai = OpenAI(
    api_key="API_KEY",
    base_url="https://api.deepinfra.com/v1/openai",
)

# Step 1: Crawl all museum links
def crawl_museum_links(base_url):
    # Request the base URL
    response = requests.get(base_url)
    if response.status_code != 200:
        print("Failed to fetch base URL!")
        return []

    # Parse HTML
    soup = BeautifulSoup(response.content, "html.parser")

    # Extract links
    museum_links = []
    for link in soup.find_all("a", href=True):  # Get all <a> tags with href
        href = link['href']
        full_url = urljoin(base_url, href)  # Handle relative URLs

        # Filter URLs containing 'muze-detay'
        if "muze-detay" in full_url:  # Looks for museum-related links
            museum_links.append(full_url)

    # Remove duplicates
    return list(set(museum_links))


# Step 1: Scrape the entire webpage
def scrape_full_content(url):
    response = requests.get(url)
    if response.status_code != 200:
        return None
    soup = BeautifulSoup(response.content, "html.parser")
    # Get the body content
    body_content = soup.find("body")
    return body_content.get_text()


# Step 2: Send content to API for processing
def process_with_api(content):
    # Create a prompt for structured data extraction
    prompt = f"""
    Extract information about the museum in Istanbul from the following html content:
    {content}

    Return the result as a valid JSON list containing:
    - "name": The name of the museum.
    - "description": A detailed body of text describing the museum. Do not shorten the text. Extract as much information as possible. 

    Output Rules:
    1. Return only the JSON output.
    2. Do not include explanations, headers, or any other text.
    3. Ensure the JSON output is properly formatted and valid.

    Example output:
    [
        {{
            "name": "Istanbul Archaeology Museums",
            "description": "The Istanbul Archaeology Museums is a group of three archeological museums located in the Eminönü district of Istanbul, Turkey..."
        }}
    ]
    """

    # API call to OpenAI
    response = openai.chat.completions.create(
        model="Qwen/QwQ-32B-Preview",
        messages=[{"role": "user", "content": prompt}],
        response_format={ "type": "json_object" }
    )

    # Extract the generated content
    result = response.choices[0].message.content

    # Return the JSON output as Python objects
    return result


# Step 4: Crawl, scrape, and process all museums
if __name__ == "__main__":
    # Crawl all museum links
    museum_links = crawl_museum_links(base_url)
    
    if not museum_links:
        print("No museum links found!")
    else:
        # Process each museum link
        for url in museum_links:
            print(f"Processing: {url}")

            # Scrape the content
            full_content = scrape_full_content(url)
            if not full_content:
                print(f"Failed to fetch content for {url}")
                continue

            # Process content with Groq
            structured_data = process_with_api(full_content)
            print(structured_data)

        # Save the structured data to a JSON file
        with open("museum_data.json", "a") as f:
            f.write(structured_data)
        print("Structured data saved to museum_data.json")
# Out:
# Processing: https://muze.gen.tr/muze-detay/tiem
# {
#     "name": "Museum of Turkish and Islamic Arts",
#     "description": "The Museum of Turkish and Islamic Arts in Istanbul is the first museum in Turkey to showcase Turkish and Islamic artworks together. It holds the distinction of being the last museum opened during the Ottoman Empire period. Established in 1914 in the imaret building of the Suleymaniye Mosque Complex, it was initially named 'Evkaf-ı Islamiye Museum' (Islamic Foundations Museum). After the declaration of the Republic and the renaming of the country to Türkiye Cumhuriyeti in 1923, it was renamed 'Turkish and Islamic Arts Museum' and moved to Ibrahim Pasha Palace in 1983.\n\nIbrahim Pasha Palace, dating back to the late 15th century, is one of the earliest surviving palace buildings and was once the residence of Grand Vizier Ibrahim Pasha. The museum underwent extensive restoration in 1982 and was reopened in 2014 to commemorate its centennial anniversary.\n\nThe museum's collection is renowned for its richness and diversity, particularly its carpet collection, which is considered the most important in the world. It includes significant examples from the Seljuk era and a wide range of Ottoman carpets, including those from Uşak with their characteristic medallions and stars. The metal, glass, and ceramic works are also noteworthy, providing insights into medieval metal arts and the evolution of science, technology, and daily life.\n\nOther valuable assets include ceramics and gypsum plaster reliefs from Seljuk and Ottoman buildings, wall paintings from Samarra, and stoneware from Raqqa. The woodwork collection features door and window shutters, sarcophagi, and book lecterns, many of which are rare surviving examples from exceptional artistic periods. The ethnography section houses collections reflecting Ottoman social life from the 18th to the 20th centuries, including textiles, items from hamams, coffee culture, and Karagöz shadow plays.\n\nWhile visiting, visitors can explore the Blue Mosque and its surroundings, including the historic park in Sultanahmet Square, the racetrack, and monuments like the Kaiser Wilhelm Fountain, Theodosius Obelisk, and Spiral Column."
# }
#
# Processing: https://muze.gen.tr/muze-detay/harem
# {
#     "name": "Topkapi Palace Harem",
#     "description": "The Harem apartment in Topkapi Palace was the private dwelling of the Ottoman Dynasty and upper-class women of the Harem for centuries. It functioned as a school with its own rules and hierarchy. The Imperial Harem is significant for its architecture and representation of styles from the 16th to 19th centuries. Access was strictly limited to Sultans, their family, and specific officials. The Harem underwent extensive construction and modifications, eventually encompassing over 300 rooms, nine baths, two mosques, a hospital, wards, and laundry facilities. Notable features include the Privy Chambers of Murad III and Ahmed III, the Twin Kiosk of the Crown Prince, and various courtyards and service buildings. The Harem is surrounded by high walls separating it from the Selamlık and other palace courtyards. A nearby attraction is the Ayasofya Hurrem Sultan Hamam, built by Mimar Sinan and named after Hürrem Sultan, the wife of Suleyman the Magnificent."
# }
#
# Processing: https://muze.gen.tr/muze-detay/turbeler
# {"name": "Turbes Museum", "description": "The Turbes Museum, located in Istanbul, Turkey, is a unique cultural institution dedicated to preserving and showcasing the historical tombs and shrines of various significant figures from Turkey's past. Established on February 15, 1978, under the Ministry of Culture and Tourism, the museum aims to maintain and exhibit the architectural and historical significance of these tombs for public appreciation and education.\n\nThe Turbes Museum Directorate manages a vast array of tombs and shrines, totaling 120, which are spread across different districts of Istanbul. These include the tomb of Suleiman the Magnificent, the tomb of Hurrem Sultan, the tomb of Fatih Sultan Mehmet Han, and the tomb of Yavuz Sultan Selim Han, among many others. Each of these tombs holds significant historical and cultural value, reflecting the architectural styles and artistic tastes of their times.\n\nThe museum is open to visitors year-round, with summer hours from 8:30 AM to 5:00 PM and winter hours from 8:30 AM to 5:00 PM. It is closed on Mondays. Visitors can explore the various tombs and learn about the lives and legacies of the individuals interred there. The museum also offers guided tours to enhance the visitor experience and provide deeper insights into the history and architecture of these remarkable structures.\n\nIn addition to its primary function of preserving and exhibiting historical tombs, the Turbes Museum also contributes to scholarly research and academic studies. The museum collaborates with institutions and researchers to document, restore, and study the tombs under its jurisdiction. This not only helps in the conservation of these historical sites but also aids in advancing our understanding of Turkey's rich cultural heritage.\n\nThe Turbes Museum is easily accessible, with its main office located in the city center of Istanbul. Visitors can reach the museum via public transportation or by car. The museum's address is İstanbul/Türkiye, and it can be contacted through its email address turbelermuzesi@ktb.gov.tr or by phone at +90(212)5182919 or +90(212)0000000. The fax number is +90(212)5170544.\n\nAdmission to the Turbes Museum is free, making it accessible to all visitors regardless of their background or financial means. This policy aligns with the museum's commitment to promoting public engagement with history and culture. The museum's dedication to preserving and sharing Turkey's rich heritage makes it a must-visit destination for anyone interested in history, architecture, and culture.\n\nIn summary, the Turbes Museum is an invaluable institution that plays a crucial role in preserving and promoting Turkey's historical and cultural legacy. Through its management of significant tombs and shrines, it offers visitors a glimpse into the lives of influential figures from the past and the architectural styles of different eras. Its commitment to education, research, and public access makes it an essential component of Istanbul's cultural landscape."}
#
# Processing: https://muze.gen.tr/muze-detay/galatakulesi
# {
#     "name": "Galata Tower Museum",
#     "description": "Also known as the Galata Kulesi Museum, an iconic symbol situated in the Galata quarter of İstanbul, Türkiye. Considered among the oldest towers in the world and one of the symbols of İstanbul, Galata Tower (Galata Kulesi) was included in the UNESCO World Heritage Temporary List in 2013. Galata Tower, one of the most important structures that make up the silhouette of İstanbul, was used as a long-term fire watchtower and was named Galata Fire Tower. Galata Tower was first built by the Byzantine Emperor Justinianos in 507-508 AD. The ancient Tower of Galata 'Megalos Pyrgos', which means Great Tower, stood on the north side of the Golden Horn in İstanbul, located in the citadel of Galata. The tower then marked the northern end of the great chain, which was expanded across the mouth of the Golden Horn to prevent enemy ships from entering the harbor. The tower contained a mechanism for raising and lowering the chain. This tower should not be confused with the present-time Galata Tower, which is still standing and located at the northernmost and highest point of the citadel of Galata. The Genoese rebuilt the current tower in 1348-49. When the Genoans captured Galata in the 1300s, they saw that most of the walls and the first tower were destroyed by the Byzantines. Ultimately, they repaired all the walls and bastions. They also rebuilt the Galata Tower, located at the top of the walls, and laid the foundations of today's tower. The tower, called 'Christea Turris' (Tower of Christ) after a cross on its cone, gradually became the symbol of this small Latin society. Marble inscription at the entrance of Galata Tower Museum: After the conquest of İstanbul, the Galata Tower was left to the Ottomans by giving the key to Fatih Sultan Mehmet on the morning of 29 May 1453. The marble inscription at the entrance indicates this: 'On the morning of Tuesday, May 29, 1453, the Genoese presented the keys of the Galata colony to Fatih Sultan Mehmed and the handover of Galata was completed on Friday, June 1.'. The tower was raised between 1445 and 46 years. It was damaged by an earthquake in the 1500's and was repaired by Architect Murad bin Hayreddin. III. After the tower is repaired during the Selim period, a bay window is added to the upper floor of the tower. In 1831, the tower suffered another fire, II. Mahmut rises two more floors above the tower and the top of the tower is covered with the famous cone-shaped roof cover. The building was last repaired in 1967. Architecture of Galata Tower: Galata Tower was built in the masonry rubble stone system. The exterior is stone mesh. The 16-line poetic inscription located above the entrance narrates that the tower was destroyed in the fire and had it repaired by Sultan Mahmud II. It is thought that the eulogy was written by poet Pertev in his name because it was built during the Mahmut period and last verse: '...Bu kulle pek metîn oldu pek a‘lâ yaptı Mahmûd Han' 1248 (1832-33). The tughra of Sultan Mahmud II between the two crescent and star motifs is scraped. The round arched window above the door was the lookout for the soldiers. It is a nine-story building after the high ground floor. The windows on the cylindrical body are brick-knit circular arches. The development of the last two floors just below the cone roof is emphasized by the profiled moldings surrounding the cylindrical body. There is an observation balcony with metal ornamented network that surrounds the floor under the cone roof. On the lower floor, there are round arches sitting on deep niche piers and brick-knit circular arched windows. Today, it is observed that the part of the building up to the third floor has a Genoese character and the other floors have an Ottoman character. The building is used today reestablished as a museum with exhibition areas by Ministry of Culture and Tourism in 2020 and opened to visitors on October 6th, 2020, which is Independence Day of İstanbul. Ahmed the wise, and his first unpowere ...
# }
#
# Processing: https://muze.gen.tr/muze-detay/kizkulesi
# {
#     "museums": [
#      {
#          "name": "Maiden's Tower Museum",
#             "description": "Located on a small islet at the southern entrance of the Bosphorus strait, 200 meters from the coast of Üsküdar neighborhood in Istanbul, the Maiden's Tower Museum is a historic and iconic landmark that dates back over two millennia. Originally built by the Athenian general Alcibiades in 408 BC as a customs station for ships coming from the Black Sea, the tower has served various purposes over the centuries, including as a defense tower, lighthouse, quarantine station, and military base during the Byzantine and Ottoman eras.",
#             "additional_information": {
#              "address": "Salacak Mah. Salacak Mevkii 34668 Üsküdar/İstanbul",
#                 "contact": {
#                  "email": "iktm34@ktb.gov.tr",
#                     "phone_numbers": [
#                      {"number": " +90(216)3424747"},
#                         {"number": " +90(216)0000000"}
#                     ],
#                 "fax": " +90(212)0000000"
#                 },
#             "ticket_price": "27€ (Euro) +5€ (Transportation fee)",
#                 "opening_hours": {
#                  "summer_period": "1 April - 1 November: Opening time 09:30 - Closing time 21:00",
#                     "winter_period": "1 November - 1 April: Opening time 09:30 - Closing time 21:00",
#                     "box_office_closing": "Summer: 20:00, Winter: 20:00",
#                     "closed_days": "Open every day"
#                 },
#             "accessibility": "Accessible by boat from Üsküdar or Galataport piers",
#                 "history": "The tower has a rich history, having been rebuilt and used by various empires and rulers. During the Ottoman conquest of Constantinople in 1453, it was destroyed and then reconstructed by Sultan Mehmed II. It has been used for various functions, including a lighthouse, quarantine station, and military base.",
#                 "current_status": "Today, it is a monument-museum managed by the Ministry of Culture and Tourism and hosts a pastry shop for visitors. It was recently restored and reopened in May 2023.",
#                 "legends": "Surrounded by numerous legends and stories, including tales of love, tragedy, and mystery, such as the stories of Leander and Hero and the Byzantine princess and the snake.",
#                 "architecture": "The tower has undergone several transformations, reflecting different architectural styles over the centuries. The current structure features a five-story, octagonal plan with baroque elements, and was restored to its early 19th-century appearance during the reign of Ottoman Sultan Mahmud II.",
#                 "restoration": "In 2023, after a two-year restoration project by the Ministry of Culture and Tourism, the tower was reopened to the public, featuring strengthened structural elements and historical features preserved with modern facilities.",
#                 "cultural_significance": "As an ancient and enduring symbol of Istanbul, the Maiden's Tower is not only a historical monument but also a cultural icon that continues to captivate visitors with its beauty and the mysteries of its past.",
#                 "amenities": "Visitors can purchase tickets online or at the piers, and an audio guide is available for a more immersive experience.",
#                 "external_links": [
#                  "https://kizkulesi.gov.tr/",
#                     "https://istanbuluseyret.ibb.gov.tr/",
#                     "https://basin.ktb.gov.tr/",
#                     "https://www.aa.com.tr/",
#                     "https://www.thebyzantinelegacy.com/"
#                 ]
#          }
# }
#     ]
# }
#
# Processing: https://muze.gen.tr/muze-detay/mozaik
# {
#     "museums": [
#      {
#          "name": "Great Palace Mosaics Museum",
#             "description": "The Great Palace Mosaics Museum is located inside the Arasta Market in the Blue Mosque Complex in Istanbul, Turkey. It showcases magnificent mosaics discovered during excavations in the northeastern section of the cloister in the Eastern Roman Grand Palace in 1935. These mosaics, dating between 450-550 AD, feature depictions from daily life, nature, and mythology, reflecting the artistic expertise of the era's leading masters.\n\nThe museum houses a collection of mosaic floors that were partially preserved in the northeastern part of the colonnaded courtyard of the Great Palace from the Eastern Roman Period. Only 180 square meters of the mosaic area have been uncovered and are displayed in the museum. The mosaics are composed of limestone, terracotta, and colored stones, with an average grain size of 5mm. The artistic techniques employed include 'Opus Vermiculite' for detailed descriptions and 'Fishscale' for white marble parts, with depictions bounded by contours.\n\nSome of the prominent mosaic scenes include a griffon eating a lizard, fighting elephant and lion, a mare nursing her colt, goose herding children, a man milking a goat, a child feeding a donkey, a young girl carrying a jug, bears eating apples, and a hunter fighting a tiger. There are approximately 150 human and animal figures and 90 different themes depicted on these mosaics.\n\nThe museum has had a history of management under different entities. It was initially under the management of the Istanbul Archaeology Museum in 1953 and became a unit of the Hagia Sophia Museum in 1979. A restoration and conservation project, carried out in collaboration with the Austrian Academy of Sciences between 1982 and 1997, has helped preserve these ancient mosaics.\n\nAdjacent to the museum, visitors can explore the renowned Blue Mosque, also known as the Sultan Ahmed Mosque, which was built in the 17th century and is famous for its Iznik tiles and numerous minaret balconies. The mosque complex is one of the largest in Istanbul and includes the tomb of Sultan Ahmed I.\n\nThe Great Palace Mosaics Museum offers a unique glimpse into the artistic and cultural heritage of the Eastern Roman Empire, providing visitors with an appreciation of the skilled craftsmanship and diverse thematic representations of that period."
#         }
#  ]
# }
#
# Processing: https://muze.gen.tr/muze-detay/adam
# {
#     "name": "Adam Mickiewicz Museum",
#     "description": "The Adam Mickiewicz Museum is a historic house museum dedicated to the life of Adam Mickiewicz, a renowned Polish poet. It is located in the Beyoğlu district on the European side of Istanbul, Turkey, and is operated under the Museum of Turkish and Islamic Arts management. Adam Mickiewicz was born on December 24, 1798, in Zaosie, near Nowogródek, and died in Istanbul on November 26, 1855. He is considered the greatest Romantic poet of Polish literature and is compared to prominent European writers of the first half of the nineteenth century, such as Lord Byron and Johann Wolfgang von Goethe. Mickiewicz worked as a teacher at the Kovno school and as a lecturer at the Lausanne Academy and the Paris Collège de France. He was also the editor-in-chief of Polish newspapers published in exile and organized Polish legions in Italy in 1848. In the years 1852-1855, he took care of a valuable collection at the Bibliothèque de l'Arsenal in Paris. In 1855, he embarked on his final journey to the East, planning to organize Polish legions to fight against Tsarist Russia during the Crimean War. He befriended Michał Czajkowski (Sadık Paşa), who commanded Polish forces in the region. Mickiewicz died suddenly from illness, likely cholera, which he may have contracted while visiting patients in tents in the Kurtuluş district, in Istanbul. The museum is located at the junction of Tatlı Badem Sokak and Serdar Ömerpaşa Caddesi Streets, on the site where Mickiewicz stayed during his final weeks. The house he rented was simple and modest, as described by a Polish visitor after his death. The building was destroyed in a fire in 1870, and an exact copy was built on the same plot by Jósef Ratyński in the same year. The museum was opened in 1955, marking the 100th anniversary of the poet's death, with the assistance of the Museum of Literature in Warsaw. The museum houses some manuscripts of Adam Mickiewicz, historical documents, and paintings. The crypt where Mickiewicz was temporarily buried for a month is located in the museum's basement."
# }
#
# Processing: https://muze.gen.tr/muze-detay/arkeoloji
# }   "description": "The Istanbul Archaeology Museums (Istanbul Arkeoloji Müzeleri) are a compound of museums which consist of three major sections: The Archaeology Museum, The Museum of the Ancient Orient, and The Tiled Kiosk Museum. These three separate main units are located in the same garden and house the palace collections formed during the late 19th century by museum director, master painter (known for 'The Tortoise Trainer' housed in Pera Museum), and archaeologist Osman Hamdi Bey. The Istanbul Archaeological Museum is the first regular museum in the history of the Ottoman Empire and Turkey, housing about a million artifacts from a variety of cultures collected from the imperial lands.\n\n**Archaeology Museum**\n\nInterest in collecting historical artifacts in the Ottoman period dates back to the reign of Mehmet the Conqueror, but the institutional emergence of museums coincides with the establishment of the Istanbul Archaeological Museums in 1869 as Müze-i Hümayun (Imperial Museum). Müze-i Humayun, housing archaeological works collected in the Hagia Irene Church, is the foundation of the Istanbul Archaeological Museum. The Tiled Kiosk, built during the reign of Mehmet the Conqueror, was converted into a museum due to the insufficiency of Hagia Irene. The Tiled Kiosk, which is still under the administration of the Istanbul Archaeological Museum, was restored and opened its doors in 1880.\n\nWhen Osman Hamdi Bey was assigned as the museum director in 1881, there was a breakthrough in Turkish museology. Osman Hamdi Bey excavated in Mount Nemrud, Myrina, Kyme, other Aeolian necropolises, and the Lagina Hekate Temple. As a result of excavations he conducted in Sayda (Sidon) between 1887-1888, he discovered the necropolis of the King of Sidon and returned to Istanbul with many sarcophagi, including the famous Alexander Sarcophagus.\n\n**The Tiled Kiosk Museum**\n\nThe oldest building (1472 CE) in the Istanbul Archaeological Museum complex is the Tiled Kiosk. Built by Ottoman Sultan Mehmed the Conqueror as a pleasure palace or kiosk, it is also known as the Glazed Kiosk (Sırçalı Köşk). The building's architecture is attributed to an unknown Persian architect due to its typical Persian facade, polygonal pillars, and stone-framed bricks. The entrance, decorated with mosaic tiles, has a 14-column marble arcade. The doorway of the kiosk is a single storey, while the back of the building adds another storey. The six rooms and the middle salon of the kiosk museum display numerous examples of Turkish tiles and ceramics from the Seljuk and Ottoman periods.\n\n**The Museum of Ancient Orient**\n\nThe building, originally established as the first academy of fine arts in the Ottoman Empire and later arranged as the Museum of Ancient Orient to house old oriental works, was built by Osman Hamdi Bey in 1883 as the School of Fine Arts (Sanayi-i Nefise Mektebi), which would later form the foundation of Mimar Sinan Fine Arts University. This academy was the first fine arts school opened in the Ottoman Empire. The architect of the building is Alexander Vallaury, who also designed the classical building of the Istanbul Archaeological Museums.\n\nAfter the academy relocated to another building in Cağaloğlu in 1917, the building was allocated to the Directorate of Museums. The museum's director at that time, Halil Edhem Bey (1861–1938), believed it would be more appropriate to display the works of ancient Near Eastern cultures separately from Greek, Roman, and Byzantine works. Thus, the building became the Museum of Ancient Orient.\n\nA new museum building was needed to display magnificent works such as the Tomb of Alexander (Alexander Sarcophagus), Tomb of the Crying Women (Sarcophagus of the Mourning Women), Lycian Tomb, and Tabnit tomb, which were brought to Istanbul from the Sidon King Necropolis excavation carried out by Osman Hamdi Bey between 1887 and 1888. Across from the Tiled Kiosk, the Classical Building of the Istanbul Archaeological M ...
# Processing: https://muze.gen.tr/muze-detay/galatamevlevi
# {
#     "name": "Galata Mevlevi House Museum",
#     "description": "The Galata Mevlevi House Museum, also known as Mevlevihanesi, is a renowned and authentic Mevlevi Whirling Dervish hall located in Istanbul, Turkey. Situated on Galip Dede Street in Beyoğlu, it is easily accessible from the bustling Istiklal Street. Historically, this lodge was referred to as Galata or Kulekapısı Mevlevi Lodge or Galip Dede Tekke during the Ottoman era.\n\nEstablished in 1491, the Galata Mevlevi Lodge holds significant historical importance and is considered one of the most important Ottoman works in Beyoğlu, alongside the Galata Palace School. Initially opened to visitors as the Divan Literature Museum in 1975, it was later reorganized and renamed as the Galata Mevlevi Lodge Museum in 2011.\n\nThe museum's layout is meticulously designed, featuring a main door with an epitaph detailing renovations carried out during the reign of Sultan Abdulmejid I. Upon entering through the gateway, visitors are greeted by the Sema area, which is covered with walnut flooring. This space is central to the Mevlevi rituals and is adorned with a mihrab (prayer niche) and a minber (pulpit) at the back. A calligraphy panel inscribed with "
# }
#
# Processing: https://muze.gen.tr/muze-detay/islam-bilim
# {
#     "name": "Museum of the History of Science and Technology in Islam",
#     "description": "The Museum of the History of Science and Technology in Islam was opened in 2008 with a concept prepared by Prof. Dr. Fuat Sezgin, an Islamic science historian. Exhibiting works, devices, and tools invented and developed by Islamic scientists between the 9th and 16th centuries, the museum consists of 12 sections including astronomy, clocks and marine, war technology, medicine, mining, physics, maths and geometry, architecture and city planning, chemistry and optics, geography, and a cinevision screening room.\n\nThe Elephant Clock is a highlight of the museum, designed by al-Jazari to showcase his admiration for the universality of Islam during its expansion from Spain to Central Asia. This mechanical masterpiece greets visitors in the entrance hall.\n\nThe Astronomy section features miniatures of important observatories from the Islamic period, astrolabes, world globes, and measuring sets. The Clock and Marine section includes sundials, clocks designed by al-Jazari and al-Biruni, mechanical clocks by Taqī al-Dīn, a chandelier clock, the Andalusian candle clock with twelve doors, and marine equipment.\n\nIn the Physics section, scale models of tools and devices described in al-Jazari's book "}
# Processing: https://muze.gen.tr/muze-detay/topkapi
# {
#     "name": "Topkapi Palace Museum",
#     "description": "Topkapi Palace Museum is located on Sarayburnu (Seraglio Point) in the historical peninsula of Istanbul, overlooking both the Marmara Sea and the Bosphorus Strait. It was the primary residence and administrative center of the Ottoman sultans for nearly four centuries, from the 15th to the 19th century. The palace complex is now a museum, attracting visitors from around the world with its rich history, magnificent architecture, and extensive collections.\n\nThe palace was built by Sultan Mehmed II, the conqueror of Constantinople, shortly after the city's conquest in 1453. Over the years, subsequent sultans expanded and modified the palace, resulting in a sprawling complex of buildings, courtyards, and gardens. The palace was home to all Ottoman sultans until the reign of Abdulmecid I in the mid-19th century, after which they moved to more European-style palaces along the Bosphorus.\n\nTopkapi Palace is divided into four main courtyards, each serving different purposes. The First Court, also known as the Court of the Janissaries or the Parade Court, was the outermost area and served as a public space. It contains several notable structures, including the Hagia Irene Museum, a Byzantine church, and the Imperial Mint (Darphane-i Âmire), which was used for producing Ottoman coins.\n\nThe Second Court, accessed through the Middle Gate, was the administrative center of the palace and the empire. It housed offices, including the Imperial Council Chamber, where government business was conducted. The Outer Treasury in this court displays a impressive collection of Ottoman and European arms and armor.\n\nThe Third Court was the sultan's private domain, guarded by white eunuchs. It included the Audience Chamber, where important officials and foreign ambassadors were received, and the Library of Ahmed III, known for its beautiful architecture and tile work. The Sacred Safekeeping Rooms in this court house relics associated with the Prophet Muhammad and other Islamic artifacts.\n\nThe Fourth Court contains various pleasure pavilions and kiosks built by different sultans, reflecting their individual tastes and the architectural trends of their times. These include the Mecidiye Kiosk, the Revan Kiosk, and the Baghdad Kiosk, each adorned with exquisite tile work and decorations.\n\nOne of the most remarkable parts of Topkapi Palace is the Harem, the residence of the sultan's family and concubines. The Harem is a labyrinthine complex of rooms, chambers, and courtyards, reflecting the intricate social hierarchy and luxurious lifestyle of the Ottoman royal family. It is known for its intricate architecture, beautiful tile work, and the stories of power, intrigue, and daily life within its walls.\n\nThe Imperial Treasury is another highlight of the palace, housing an incredible collection of jewels, weapons, and other precious objects. Notable items include the Topkapi Dagger, adorned with large emeralds and a watch set into the pommel, and the Spoonmaker's Diamond, one of the largest and most famous diamonds in the world.\n\nTopkapi Palace also features extensive gardens and landscaped areas, providing a serene contrast to the grandeur of the buildings. The palace's location offers panoramic views of the Golden Horn, the Bosphorus, and the Marmara Sea, enhancing its aesthetic appeal.\n\nToday, Topkapi Palace Museum is a UNESCO World Heritage Site and one of the most popular tourist attractions in Istanbul. It offers visitors a glimpse into the opulent world of the Ottoman sultans, their courtiers, and their families, as well as insights into the political, social, and cultural history of the Ottoman Empire.\n\nVisitors can explore the various courts, pavilions, and galleries, each with its own unique exhibits and stories. The museum also hosts temporary exhibitions and cultural events, further enriching the visitor experience. Despite its long history and the many changes it has undergone, Topkapi Palace remains an iconic sym ...
# }
#
# Processing: https://muze.gen.tr/muze-detay/rumeli
# {"name": "Rumeli Fortress", "description": "The Rumeli Fortress, also known as Bogazkesen Castle, is a significant historical and architectural landmark located in the Sarıyer district of Istanbul, Turkey. Constructed in just four months in 1452 by Sultan Mehmed II, the fortress played a crucial role in the Ottoman Empire's strategic plans, particularly in controlling the maritime traffic through the Bosphorus Strait prior to the conquest of Constantinople in 1453.\n\nThe fortress was designed by the architect Muslihiddin Ağa and was built with the labor of thousands of workers. It consists of several key components, including main gates such as the Mountain Gate, Dizdar Gate, Hisarpeçe Gate, and Sel Gate, as well as secondary gates like the Cemetery Gate. The fortress features 17 towers, among which the Saruca Pasha Tower, Halil Pasha Tower, and the two Zaganos Pasha Towers are the most prominent.\n\nEach tower served specific functions and was named after prominent figures of the Ottoman administration during that period. For instance, the Saruca Pasha Tower is a cylindrical structure with seven floors, featuring acoustic properties that allow clear communication across its chambers. The Halil Pasha Tower, with its dodecagonal plan, stands on the seaside axis of the fortress, while the Zaganos Pasha Tower is circular and was completed in Rajab 856 (July-August 1452), as inscribed on its marble doorframe, making it the first Turkish inscription on the Bosphorus.\n\nThroughout its history, the Rumeli Fortress has served various purposes beyond its initial military function. After the conquest of Istanbul, it was used as a imperial prison, customs checkpoint, and even as a residential area where a small district developed within its walls. The fortress suffered damage from earthquakes and fires over the centuries but underwent significant restoration work in the 20th century, particularly in 1953 under the direction of President Celal Bayar, and was opened to the public as a museum in 1968.\n\nToday, the Rumeli Fortress Museum is a testament to Ottoman military architecture and engineering prowess. Visitors can explore the fortress's towers, gates, and the lush garden that offers breathtaking views of the Bosphorus. The museum exhibits artifacts such as cannonballs, balls, and a section of the chain that was used to block the Golden Horn against naval attacks. The fortress also houses the Abu'l-Feth Mosque, which was rebuilt in 2015 and is the first mosque in Istanbul where Sultan Mehmed II prayed with his soldiers, teachers, and viziers.\n\nGetting to the Rumeli Fortress Museum is relatively straightforward, with accessible public transportation options from key areas like Sultanahmet and Taksim. Visitors can take tramway lines, buses, or even利用新的架空铁路线和地铁连接轻松到达。\n\n总的来说，Rumeli Fortress不仅是历史的见证，也是现代游客探索伊斯坦布尔丰富文化遗产的必访之地。其壮丽的建筑、战略性的位置以及与拜占庭和奥斯曼帝国历史的深刻联系，使其成为理解这一地区过去的关键窗口。"}
#
# Processing: https://muze.gen.tr/muze-detay/havaalani
# {
#     "name": "Istanbul Airport Museum",
#     "description": "The Istanbul Airport Museum is located at the Istanbul New Airport and opened its doors on July 17, 2020. It features an exhibition titled 'Treasures of Türkiye: Faces of the Throne,' which displays 316 different items from 29 museums across Türkiye, including the 'Kadesh Treaty,' considered the first peace treaty in human history. The museum's aim is to showcase twelve thousand years of Anatolian history through the theme of 'Rule and Ruler,' covering periods from prehistoric times to the modern Turkish era. Spanning an area of 1,000 square meters on the international departures floor, it is one of the few museums of its kind globally. The museum plans to host a new temporary exhibition annually, with the first exhibition acting as a miniature 'Anatolian Civilizations Museum' featuring artifacts from various civilizations such as Hittite, Urartu, Phrygian, Lydian, Roman, Byzantine, Seljuk, Ottoman, and more. It is open daily from 8:30 AM to 11:00 PM, and admission costs 13€, with free entry for children under eight. Museum passes for Türkiye and Istanbul are not valid for this museum."
# }
#
# Processing: https://muze.gen.tr/muze-detay/ayairini
# }   "description": "Hagia Irene Museum, located in the outer courtyard of Topkapı Palace in Istanbul, is the oldest church of the Eastern Roman Empire (Byzantine) and the second largest church in Istanbul after Hagia Sophia. The museum holds significant historical and architectural importance, showcasing a blend of Byzantine and Ottoman influences.\n\n**History and Architecture**\nHagia Irene, meaning 'sacred peace,' was originally built in 330 AD out of wood and later reconstructed in the 6th century during the reign of Emperor Justinianus after being damaged in the Nika Revolt of 532 AD. The church underwent further renovations in the 8th century following damages from an earthquake, transforming its appearance into the domed church with a basilical plan that is seen today.\n\nThe structure consists of three main sections: naos, narthex, and atrium, making it the only surviving example of a Byzantine church with a standing atrium. It was built as a three-nave basilica during the reign of Constantine the Great and was later renovated by Leo III and his son Constantine Copronymus during the Iconoclastic period.\n\n**Usage Over Time**\nAfter the fall of Constantinople, Hagia Irene was not converted into a mosque and was instead used as a warehouse for weapons (known as the Harbiye Warehouse) due to its sturdy construction. Over the centuries, it served various purposes, including being a weapons depot and a museum. In the 19th century, it was officially recognized as the first official museum in the country, known as Müze-i Hümayun (Imperial Museum). Later, it housed the weapons collection and served as the first Military Museum between 1908 and 1940.\n\n**Current Status**\nToday, Hagia Irene Museum stands as a testament to the rich history of Istanbul, offering visitors a glimpse into the architectural and cultural heritage of the Byzantine and Ottoman Empires. It is open to the public, and its unique setting within the Topkapı Palace complex makes it a popular destination for history and architecture enthusiasts.\n\n**Contact and Practical Information**\n- **Address:** Cankurtaran, Topkapı Sarayı, No:1, 34122 Fatih/İstanbul\n- **Email:** info@millisaraylar.gov.tr\n- **Phone:** +90(212)5120480, +90(212)0000000\n- **Fax:** +90(212)0000000\n- **Ticket Price:** 600 ₺\n- **Open Hours:** Summer (1 April - 1 October): 09:00 - 18:00; Winter (1 October - 1 April): 09:00 - 18:00\n- **Closed Days:** Tuesday\n- **Box Office Closing:** Summer - 17:30, Winter - 17:30\n\n**Additional Information**\nHagia Irene Museum is renowned for its well-preserved Byzantine architecture and its role in the development of museology in Turkey. The museum's collections and exhibitions provide valuable insights into the military history and artifacts of the Ottoman Empire. Visitors can explore the church's interior, admire its architectural features, and learn about its transformation over the centuries.\n\n**Official Announcements**\nTickets for Hagia Irene are valid for one day from the date of purchase. It is advisable to check the official website or contact the museum for any updates or special exhibitions before planning a visit.\n\n**External Links**\n- [Kulturportali.gov.tr](https://www.kulturportali.gov.tr/): Aya Irini Kilise Muzesi\n- [Iae.org.tr](https://blog.iae.org.tr/): Ottoman Era Hagia Irene\n- [Tbmm.gov.tr](https://acikerisim.tbmm.gov.tr/): Hagia Irene Military Museum Photo Album\n- [Thebyzantinelegacy.com](https://www.thebyzantinelegacy.com/): Hagia Eirene\n- [Ktb.gov.tr](https://www.ktb.gov.tr/): Aya Irini\n\n**Last Updated:** Tuesday, 10 September 2024"
# Processing: https://muze.gen.tr/muze-detay/fethiye
# {"name": "Fethiye (Pammakaristos) Museum", "description": "The Fethiye (Pammakaristos Church) Mosque/Museum is located on the fifth hill of Constantinople in the modern neighborhood of Çarsamba, Istanbul. It is a Middle Byzantine Church, founded during the Komnenian era, with late Byzantine additions, notable for its extensively decorated parekklesion. The church was likely founded by John Komnenos and his wife, Anna Doukaina, and served as a mausoleum for their family. After the reconquest of Constantinople by the Byzantines in 1261, it came into the possession of Michael Tarchaneiotes Glabas, who restored the church. His widow, Maria, built a four-columned parekklesion with a two-storied narthex as a funerary chapel and decorated it with exquisite mosaics.\n\nThe katholikon of Pammakaristos is an ambulatory type of cross-domed church, with the central bay separated from the rest of the interior. The ambulatory surrounds the 12th-century building on the northern, western, and southern sides and contains several tombs. The parekklesion, dedicated to Christ, was added in the south side around 1310 by Maria to house the tomb of her husband. It is a cross-in-square with an apse, a naos covered by a dome, and a narthex with a gallery topped by two domes. The tomb of Michael and Maria is located under an arcosolium in the naos's northern wall. The parekklesion features mosaics depicting scenes from the life of Christ, groups of saints, and a Deesis in the main apse.\n\nFrom around 1455 to 1587, the church served as the seat of the Patriarchate under Gennadios II Scholarios. In 1587, it was converted into a mosque, named Fethiye Mosque, to commemorate the Ottoman conquest of Georgia. Significant alterations were made during this conversion, including the replacement of the tripartite bema with a qibla wall, modification of columns to arches, addition of a minaret, and removal of parts of the walls to create a larger space. The mosque underwent restorations in 1640 and around 1845 during the reign of Sultan Abdulmecid. Further restorations took place in 1938-1940, after which the parekklesion was turned into a museum. The mosaics in the parekklesion were uncovered by the Byzantine Institute in Istanbul starting in 1950. Today, the parekklesion operates as a museum, offering visitors a glimpse into its rich历史 and artistic heritage.\n\nReferences:\n- https://www.kulturportali.gov.tr/\n- https://www.archnet.org/"}
#
# Processing: https://muze.gen.tr/muze-detay/ayasofya
# {
#     "museums": [
#      {
#          "name": "Hagia Sophia Grand Mosque",
#             "description": "The Hagia Sophia Grand Mosque / Ayasofya-i Kebir Cami-i Sherifi is located in Istanbul, Turkey. It is one of the most famous and significant architectural landmarks in the world. Originally built as a church in 537 AD during the reign of the Byzantine Emperor Justinian I, it served as the patriarchal cathedral of the Eastern Orthodox Church. In 1453, after the Ottoman conquest of Constantinople, it was converted into a mosque by Sultan Mehmed II. In 1935, it was secularized and opened as a museum by the Republic of Turkey. However, on July 10, 2020, it was converted back into a mosque.\n\nHagia Sophia is renowned for its massive dome, which was the largest in the world for nearly a thousand years. The building's innovative design was created by the Greek scientists Anthemius of Tralles and Isidore of Miletus. The dome measures over 31 meters in diameter and is set on pendentives, allowing for an unprecedented degree of openness in the interior space.\n\nInside the Hagia Sophia, visitors can see a unique blend of Christian mosaics and Islamic elements. The Christian mosaics feature images of Jesus, Mary, and various saints, while the Islamic elements include calligraphic roundels with the names of Allah, Muhammad, and the first four caliphs, as well as mihrabs and minbars.\n\nFour minarets surround the mosque, constructed at different times. The minaret in the southeast corner is thought to be the oldest, while the other three were built by the renowned Ottoman architect, Mimar Sinan, in the 16th century.\n\nThe Hagia Sophia has undergone numerous restorations and repairs over the centuries due to earthquakes and other damages. In the 19th century, extensive restoration work was carried out by the Fossati brothers, who also discovered and restored many of the building's original mosaics.\n\nIn addition to its religious and architectural significance, Hagia Sophia has played a role in politics and cultural heritage. Its conversion back into a mosque in 2020 has been a subject of international debate and controversy, with some arguing that it undermines its status as a symbol of interfaith dialogue and universal heritage.\n\nToday, Hagia Sophia remains one of the most visited tourist attractions in Turkey, drawing millions of visitors each year who come to marvel at its architecture, history, and the intricate artwork that adorns its walls."
#         }
# ]
# }
#
# Structured data saved to museum_data.json

# %%
from openai import OpenAI
import json

# Create OpenAI client
openai = OpenAI(
    api_key="API_KEY",
    base_url="https://api.deepinfra.com/v1/openai",
)

def generate_qa_istanbul(content,model="Qwen/Qwen2.5-72B-Instruct"):
    prompt = f""" 
        Analyze the following content about Istanbul and generate question-answer pairs strictly based on the provided text. 
        Content:
        {content}

        Instructions:
        1. Write clear and self-contained questions that do not require referring back to the content. 
        2. Ensure the questions can stand alone and provide informative context. 
        3. Focus on facts, dates, locations, and cultural insights directly mentioned in the text. 
        4. Avoid vague questions like "What is mentioned in the text?" or any that depend on the reader having access to the content. 
        5. If the content lacks enough information, generate fewer questions or return an empty list. 
        6. Generate as many questions as possible based on the content provided. But the questions should be relevant and meaningful.
        7. Give just the JSON output. Do not include any other information.
        8. Provide the output as a Python list in JSON format:
        Example Output:
        [
            {{"question": "When was Hagia Sophia built?", "answer": "537 AD"}},
            {{"question": "What was the original purpose of Hagia Sophia?", "answer": "A church."}}
        ]
        """

    # API call to OpenAI
    response = openai.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        response_format={ "type": "json_object" }
    )

    # Extract the generated content
    result = response.choices[0].message.content
    result = json.loads(result)
    # Return the JSON output as Python objects
    return result

# %%
# Open the JSON file containing museum data
with open("museum_data.json", "r") as f:
    museum_data = json.load(f)

# Create a list to store all questions
all_questions = []

# Loop through each museum
for museum in museum_data:
    content = museum["description"]
    museum_name = museum["name"]
    
    # Generate questions for each museum (assuming the function returns a list of dictionaries)
    questions = generate_qa_istanbul(content)
    print(questions)
    questions = questions.get('questions')
    # Format each question into the required structure
    for q in questions:
        if q == 0:
            break
        all_questions.append({
            "museum": museum_name,
            "question": q["question"],
            "answer": q["answer"]
        })


# Write all questions to a single JSON file
with open("questions.json", "w") as f:
    json.dump(all_questions, f, indent=4)  # Pretty-print with indentation

print("All questions saved to questions.json")
# Out:
# {'questions': [{'question': 'In which city is the Hagia Sophia Grand Mosque located?', 'answer': 'İstanbul'}, {'question': 'What was the original name of the Hagia Sophia?', 'answer': 'Megale Ekklesia (Big Church)'}, {'question': 'When was the first church of Hagia Sophia built?', 'answer': '360 AD'}, {'question': 'Who constructed the first church of Hagia Sophia?', 'answer': 'Emperor Konstantios'}, {'question': 'What happened to the first church of Hagia Sophia in 404?', 'answer': 'It was burned down after a public riot.'}, {'question': 'When was the second church of Hagia Sophia built?', 'answer': '415'}, {'question': 'Who constructed the second church of Hagia Sophia?', 'answer': 'Emperor Theodosios II'}, {'question': 'What significant event caused the second church to be demolished in 532?', 'answer': 'The Nika revolts during Emperor Justinianos’ reign'}, {'question': 'When was the current Hagia Sophia built?', 'answer': '532'}, {'question': 'Who were the architects of the current Hagia Sophia?', 'answer': 'Anthemios of Tralles and Isidoros of Miletos'}, {'question': 'How long did it take to build the current Hagia Sophia?', 'answer': 'Five years'}, {'question': 'What did Emperor Justinianos allegedly say on the opening day of Hagia Sophia?', 'answer': 'My Lord, thank you for giving me the chance to create such a worshipping place. Süleyman, I beat you.'}, {'question': 'What is the architectural design of Hagia Sophia based on?', 'answer': 'It combined the three traditional basilical plans with the central dome plan'}, {'question': 'How many columns does Hagia Sophia have?', 'answer': '104 columns'}, {'question': 'From where were the marbles and columns used in Hagia Sophia brought?', 'answer': 'Ancient cities in Anatolia and Syria, such as Aspendus, Ephesus, Baalbek, and Tarsus'}, {'question': 'What materials were used to decorate the walls of Hagia Sophia?', 'answer': 'Gold, silver, glass, terra cotta, and colorful stones'}, {'question': 'When was Hagia Sophia converted into a museum?', 'answer': '1934'}, {'question': 'When did Hagia Sophia reopen as a mosque?', 'answer': 'July 24, 2020'}, {'question': 'Who attended the reopening ceremony of Hagia Sophia as a mosque?', 'answer': 'President Recep Tayyip Erdoğan'}, {'question': 'What is the height of the dome of Hagia Sophia?', 'answer': '55.60 meters'}, {'question': 'What does the dome of Hagia Sophia represent in Islamic architecture?', 'answer': 'The heavens and the oneness of Allah'}, {'question': 'Who created the calligraphic roundels inside Hagia Sophia?', 'answer': 'Kazasker Mustafa İzzet Efendi'}, {'question': 'What do the calligraphic roundels inside Hagia Sophia include?', 'answer': 'The names of Allah, Muhammad, and the first four caliphs, along with the grandsons of the Prophet'}, {'question': 'What is the length of Hagia Sophia from the apsis to the outer narthex?', 'answer': '100 meters'}, {'question': 'What is the width of Hagia Sophia?', 'answer': '69.5 meters'}, {'question': 'What are some of the artifacts found in Hagia Sophia?', 'answer': 'Marble lustration urns from Pergamon, mosaics of angels, and relics from different periods'}, {'question': 'What is the Omphalion in Hagia Sophia?', 'answer': 'The place where Byzantine emperors were crowned'}, {'question': 'What is the operating schedule of Hagia Sophia?', 'answer': 'Open every day from 09:00 to 19:30, with a box office closing at 19:00'}, {'question': 'How much does it cost for foreign visitors to enter Hagia Sophia?', 'answer': '25€'}, {'question': 'What attire is required for women to enter Hagia Sophia?', 'answer': 'Women must wear a head covering and appropriate attire'}, {'question': 'What does the Deesis Mosaic in the upper gallery depict?', 'answer': 'Mary, Jesus, and John the Baptist'}]}
# {'questions': [{'question': 'In which year was the Turkish and Islamic Art Museum initially established?', 'answer': '1914'}, {'question': 'What was the original name of the Turkish and Islamic Art Museum when it was established?', 'answer': 'Evkaf-ı Islamiye Museum (Islamic Foundations Museum)'}, {'question': 'Who was the founder of the Turkish and Islamic Art Museum?', 'answer': 'Osman Hamdi Bey'}, {'question': 'What was the purpose of establishing the Turkish and Islamic Art Museum?', 'answer': 'To prevent thefts from historic waqf and religious foundation buildings such as mosques, dervish lodges, and tombs'}, {'question': 'Where was the Turkish and Islamic Art Museum initially located?', 'answer': 'In the imaret building of the Süleymaniye Mosque Complex'}, {'question': 'In which year was the Turkish and Islamic Art Museum renamed and relocated to İbrahim Pasha Palace?', 'answer': '1983'}, {'question': 'Why was the İbrahim Pasha Palace gifted to İbrahim Pasha of Pargali?', 'answer': 'It was gifted by Suleiman the Magnificent, his grand vizier'}, {'question': 'What is the significance of the İbrahim Pasha Palace in terms of Ottoman architecture?', 'answer': 'It is one of the most significant structures of Ottoman civil architecture'}, {'question': 'In which year was the museum reopened after extensive restoration work?', 'answer': '2014'}, {'question': "How many pieces are in the museum's carpet collection?", 'answer': '1,700 pieces'}, {'question': "What are some of the types of carpets included in the museum's collection?", 'answer': 'Seljuk-era carpets, Ottoman prayer rugs, carpets with animal figures, and Anatolian styles such as Holbein and Lotto patterns, as well as Uşak carpets adorned with medallions and stars'}, {'question': 'What kinds of artifacts are included in the metal, glass, and ceramic works collection?', 'answer': 'Medieval metal arts, everyday tools, implements dating from the 12th century to the Ottoman period, ceramics, and gypsum plaster reliefs salvaged from Seljuk and Ottoman buildings, wall paintings from Abbasid-era palaces in Samarra, and stoneware from Raqqa'}, {'question': 'What materials are used in the woodwork collection of the museum?', 'answer': 'Pearl, ivory, and tortoise shell for inlays'}, {'question': 'What periods do the stonework artifacts in the museum span?', 'answer': 'Early Islamic, Seljuk, and Ottoman periods'}, {'question': 'What are some notable items in the ethnography section of the museum?', 'answer': 'Textiles, hammam-related items, coffee accessories, and materials used in Karagöz shadow plays'}, {'question': 'What are some notable landmarks in Sultanahmet Square?', 'answer': 'The racetrack from Byzantine times, the Kaiser Wilhelm Fountain, the Theodosius Obelisk, and the Spiral Column'}, {'question': "What are the museum's summer hours?", 'answer': '09:00–21:00'}, {'question': "What are the museum's winter hours?", 'answer': '09:00–18:30'}, {'question': 'When does the box office close during summer?', 'answer': '20:00'}, {'question': 'When does the box office close during winter?', 'answer': '17:30'}, {'question': 'How much is the admission fee to the museum?', 'answer': '17€'}, {'question': 'Can tickets to the museum be purchased online?', 'answer': 'Yes'}, {'question': 'What is the address of the Turkish and Islamic Art Museum?', 'answer': 'Binbirdirek Mah. At Meydanı Cad. No:12, 34122 Sultanahmet/İstanbul'}]}
# {'questions': [{'question': 'What was the primary purpose of the Harem apartment in Topkapi Palace?', 'answer': 'It served as the private residence of the Ottoman Sultans and their families.'}, {'question': 'Who lived in the Harem?', 'answer': "Members of the Ottoman Dynasty, upper-class women, and the Sultan's family, including his mother, wives, children, the Qadi, the Chief Consort, concubines, and eunuch guards."}, {'question': 'What architectural periods does the Harem represent?', 'answer': 'The Harem represents styles from the 16th to the 19th centuries.'}, {'question': 'Who was the Harem accessible to?', 'answer': 'The Harem was accessible only to the Sultan, his mother, wives, children, the Qadi, the Chief Consort, concubines, and eunuch guards.'}, {'question': 'During whose reign did the construction of the Harem begin?', 'answer': 'The construction began during the reign of Sultan Suleyman the Magnificent.'}, {'question': "What significant event marked the beginning of the Harem's use?", 'answer': 'Sultan Suleyman the Magnificent relocated with his wife Hürrem Sultan and family to the Harem.'}, {'question': 'How many rooms and baths does the Harem have?', 'answer': 'The Harem features over 300 rooms and 9 baths.'}, {'question': 'What notable architectural elements are found in the Harem?', 'answer': 'The Harem is adorned with Kütahya and Iznik tiles, and includes two mosques, a hospital, wards, laundry facilities, barracks, and kiosks.'}, {'question': 'Who designed the Privy Chamber of Murad III?', 'answer': 'The Privy Chamber of Murad III was designed by architect Mimar Sinan.'}, {'question': 'What is the Privy Chamber of Ahmed III also known as?', 'answer': 'The Privy Chamber of Ahmed III is also known as the Fruit Room.'}, {'question': 'What era does the Fruit Room reflect?', 'answer': 'The Fruit Room reflects the floral aesthetics of the Tulip Era.'}, {'question': 'What are the notable sections of the Harem that visitors can explore?', 'answer': 'Notable sections include the Main Entrance, the Court of the Concubines, the Imperial Hall, the Apartments of the Queen Mother, the Baths of the Sultan and the Queen Mother, the Courtyard of the Favorites, the Wards of Tressed Halberdiers, the Pipe Room, and the Bath of Tressed Halberdiers.'}, {'question': 'What is the Twin Kiosk also known as?', 'answer': 'The Twin Kiosk is also known as the Apartments of the Crown Prince.'}, {'question': 'What is a unique feature of the Twin Kiosk?', 'answer': 'The Twin Kiosk is known for its interior fountains.'}, {'question': 'Who commissioned the Ayasofya Hurrem Sultan Hamam?', 'answer': 'The Ayasofya Hurrem Sultan Hamam was built by Mimar Sinan in honor of Hürrem Sultan.'}, {'question': 'Where is the Ayasofya Hurrem Sultan Hamam located?', 'answer': 'The Ayasofya Hurrem Sultan Hamam is located between the Hagia Sophia and the Blue Mosque.'}, {'question': 'What is the architectural design of the Ayasofya Hurrem Sultan Hamam?', 'answer': 'The hamam was designed with symmetrical sections for men and women, marking an architectural innovation.'}, {'question': 'When did the Ayasofya Hurrem Sultan Hamam open and close, and when did it reopen?', 'answer': 'The hamam opened until 1910, remained closed for many years, and then reopened as a historical landmark.'}, {'question': 'On which days is the Harem open to visitors?', 'answer': 'The Harem is open every day except Tuesdays.'}, {'question': 'What are the visiting hours for the Harem during summer and winter?', 'answer': 'Summer visiting hours (1 April - 1 October) are from 09:00 to 18:00, and winter hours (1 October - 1 April) are also from 09:00 to 18:00.'}, {'question': 'When does the box office close for the Harem?', 'answer': 'The box office closes at 17:30 in both summer and winter periods.'}, {'question': 'What is the admission price for the Harem?', 'answer': 'The admission price is 600 ₺.'}, {'question': 'What is the address of the Harem?', 'answer': 'The address is Cankurtaran ...
# {'questions': [{'question': 'When was the Türbeler Museum in Istanbul established?', 'answer': 'February 15, 1978'}, {'question': 'Which ministry manages the Türbeler Museum?', 'answer': 'Ministry of Culture and Tourism'}, {'question': 'How many significant tombs and mausoleums does the Türbeler Museum oversee?', 'answer': '120'}, {'question': 'Which historical figures are buried in the tombs managed by the Türbeler Museum?', 'answer': 'Suleiman the Magnificent, Hürrem Sultan, Fatih Sultan Mehmet Han, Yavuz Sultan Selim Han, Sultan Abdülhamid I, Sultan Abdülmecid, Sultan Ahmed I, Sultan Bayezid II, Sultan Mahmud II, and Sultan Mehmed II (Fatih)'}, {'question': 'What are some of the prominent viziers and scholars whose tombs are managed by the museum?', 'answer': 'Mimar Sinan, Sokullu Mehmed Paşa, Yahya Efendi, and Şeyh Galib Dede'}, {'question': 'What are the opening hours of the Türbeler Museum?', 'answer': '08:30 to 17:00, daily except Mondays'}, {'question': 'Is there an admission fee to visit the Türbeler Museum?', 'answer': 'No, admission is free'}, {'question': 'Where is the Türbeler Museum located?', 'answer': 'Istanbul, Türkiye'}, {'question': 'What architectural and artistic styles are showcased in the tombs managed by the museum?', 'answer': 'Intricate tile work, carved wood, and stone reliefs'}, {'question': 'Which tomb is part of the Süleymaniye mosque complex?', 'answer': 'Tomb of Hürrem Sultan'}, {'question': 'Who designed the Süleymaniye mosque complex?', 'answer': 'Mimar Sinan'}, {'question': 'In which districts of Istanbul are the tombs managed by the Türbeler Museum located?', 'answer': 'Eminönü, Eyüp, Fatih, Üsküdar, and Beşiktaş'}, {'question': 'What is the significance of the tombs managed by the Türbeler Museum?', 'answer': 'They are places of historical significance, pilgrimage sites, and cultural landmarks'}, {'question': "Which significant religious figure's tomb is managed by the Türbeler Museum?", 'answer': 'Eyüp Sultan'}, {'question': 'What are the names and locations of some of the tombs managed by the Türbeler Museum?', 'answer': 'Tombs of Ahmed Paşa in Vefa, Ali Paşa in Beşiktaş, Bayram Paşa in Cerrahpaşa, Ebu Vefa in Vefa, and Hafsa Sultan in Fatih'}, {'question': 'What are some of the architectural marvels managed by the Türbeler Museum?', 'answer': 'Şehzade Tombs in Fatih and Beşiktaş'}]}
# {'questions': [{'question': 'What is Galata Tower Museum also known as?', 'answer': 'Galata Kulesi Museum'}, {'question': 'In which quarter of İstanbul is Galata Tower located?', 'answer': 'Galata'}, {'question': 'When was Galata Tower included in the UNESCO World Heritage Temporary List?', 'answer': '2013'}, {'question': 'What was one of the uses of Galata Tower in the past?', 'answer': 'A long-term fire watchtower'}, {'question': 'What was the original name of the ancient Galata Tower?', 'answer': 'Megalos Pyrgos, meaning Great Tower'}, {'question': 'What year did the Byzantine Emperor Justinianos first build the Galata Tower?', 'answer': '507-508 AD'}, {'question': 'What was the purpose of the great chain at the ancient Galata Tower?', 'answer': 'To prevent enemy ships from entering the harbor'}, {'question': 'Who rebuilt the current Galata Tower and when?', 'answer': 'The Genoese rebuilt it in 1348-49'}, {'question': 'What was the name of the tower after the Genoese rebuilt it and why?', 'answer': 'Christea Turris (Tower of Christ) because of a cross on its cone'}, {'question': 'When did Fatih Sultan Mehmet receive the keys to the Galata Tower?', 'answer': 'On the morning of May 29, 1453'}, {'question': 'What was the tower raised by Fatih Sultan Mehmet between the years 1445 and 1446 used for?', 'answer': 'It was used as a fire watchtower'}, {'question': 'Who repaired the Galata Tower after it was damaged by an earthquake in the 1500s?', 'answer': 'Architect Murad bin Hayreddin'}, {'question': "What significant change was made to the tower during Sultan Mahmut II's reign?", 'answer': 'Two more floors were added above the tower, and the top was covered with a cone-shaped roof cover'}, {'question': 'When was the Galata Tower last repaired?', 'answer': '1967'}, {'question': 'What is the construction system of Galata Tower?', 'answer': 'Masonry rubble stone system'}, {'question': 'What is the poetic inscription at the entrance of Galata Tower about?', 'answer': 'It narrates that the tower was destroyed in a fire and was repaired by Sultan Mahmud II'}, {'question': 'Who wrote the eulogy on the inscription at the entrance of Galata Tower?', 'answer': 'Poet Pertev'}, {'question': 'What is the structure of the Galata Tower from the lower floor to the upper floors?', 'answer': 'The part of the building up to the third floor has a Genoese character, and the other floors have an Ottoman character'}, {'question': "What is the height of the Galata Tower's tunnel and what is it made of?", 'answer': '70 cm wide and 140 cm high, made of stone'}, {'question': 'What was the tunnel in the Galata Tower used for during the Genoese period?', 'answer': 'A secret escape route'}, {'question': 'What significant event involving Hezârfen Ahmed Çelebi took place at the Galata Tower?', 'answer': 'Hezârfen Ahmed Çelebi jumped from the Galata Tower in 1632, flew across the Bosphorus, and landed in Üsküdar Doğancılar'}, {'question': "What was Hezârfen Ahmed Çelebi's reward from Sultan Murad IV?", 'answer': 'A bag of gold'}, {'question': 'What was the fate of Hezârfen Ahmed Çelebi after his flight?', 'answer': 'He was exiled to Algeria'}, {'question': 'What significant artifacts were found during the excavation of the Galata Tower in 1965?', 'answer': 'Human skeletal remains, four skulls, ancient coins, and an inscription'}, {'question': 'What did the authorities conclude about the skeletal remains found during the excavation?', 'answer': 'They belonged to convicts who died while trying to dig a secret path from the tower'}, {'question': 'What changes were made to the buildings around the Galata Tower in the new town?', 'answer': 'Adjacent buildings, fortification walls, Turkish cemetery, and gates were destroyed, and styleless masonry houses and apartments took their places'}, {'question': 'What is the Galata Tower Museum vicinity known for?', 'answer': 'Being a social activities and a hustling cultural hub with monuments, experiences, and sights'}]}
# {'questions': [{'question': 'What is the Turkish name for the Maiden’s Tower?', 'answer': 'Kız Kulesi'}, {'question': 'What is the Maiden’s Tower also known as during the medieval Byzantine period?', 'answer': 'Leander’s Tower or Tower of Leandros'}, {'question': 'Where is the Maiden’s Tower located?', 'answer': 'On a small islet at the southern entrance of the Bosphorus strait, 200 m (220 yd) from the coast of Üsküdar neighborhood in İstanbul'}, {'question': 'When was the Maiden’s Tower originally built?', 'answer': '408 BC'}, {'question': 'Who originally built the Maiden’s Tower?', 'answer': 'The Athenian general Alcibiades'}, {'question': 'What was the original purpose of the Maiden’s Tower?', 'answer': 'A custom station for ships coming from the Black Sea'}, {'question': 'What was the purpose of the chain between the Maiden’s Tower and the Mangana Monastery in Sarayburnu?', 'answer': 'To prevent enemy ships from entering the Bosphorus'}, {'question': 'Which Byzantine emperor had a defense tower built on the islet in the 12th century?', 'answer': 'Manuel Komnenos the First'}, {'question': 'What did Sultan Mehmed II do with the Maiden’s Tower after the Ottoman conquest of Constantinople in 1453?', 'answer': 'He had it reconstructed'}, {'question': 'What functions did the Maiden’s Tower serve during the Ottoman era?', 'answer': 'It served as a lighthouse, a quarantine station, and a military base'}, {'question': 'What is the current status of the Maiden’s Tower?', 'answer': 'It is a monument-museum under the management of the culture and tourism ministry and hosts a pastry shop'}, {'question': 'How can visitors reach the Maiden’s Tower?', 'answer': 'By boat from Üsküdar or Galataport piers'}, {'question': 'What are the operating hours of the Maiden’s Tower?', 'answer': 'Every day from 09:00 to 20:00'}, {'question': 'What are some of the legends associated with the Maiden’s Tower?', 'answer': "One legend is about a Byzantine emperor's daughter prophesied to die from a snake bite, and another is based on the Greek myth of Hero and Leandros"}, {'question': 'What was the purpose of the lantern placed on the northern part of the wooden tower by Sultan III, Ahmed’s Grand Vizier, Nevşehirli Damat İbrahim Pasha?', 'answer': 'To illuminate the way for ships coming from the Black Sea and Marmara at night'}, {'question': 'What was the Maiden’s Tower used for between 1830 and 1831 during the cholera epidemic?', 'answer': 'It was converted into a quarantine hospital'}, {'question': 'During which epidemic were some patients isolated in the Maiden’s Tower?', 'answer': 'During the plague epidemic between 1836-1837'}, {'question': 'Who added a lantern to the Maiden’s Tower, and to which administration was it transferred?', 'answer': 'A French company added a lantern, and it was transferred to the Lighthouses Administration'}, {'question': 'What additional function did the lantern on the Maiden’s Tower serve besides illuminating the way for ships?', 'answer': 'It was used as a gas tank'}, {'question': 'What was the Maiden’s Tower used for in terms of maritime safety?', 'answer': 'A light was turned on in the tower in the evenings, and a foghorn was blown in low-visibility weather'}, {'question': 'What was the Maiden’s Tower used as under the Ministry of National Defence?', 'answer': 'A surveillance and radar station'}, {'question': 'When was the Maiden’s Tower transferred to the Maritime and Port management of Türkiye?', 'answer': 'In 1983'}, {'question': 'What unusual use did the Maiden’s Tower have in the 1990s?', 'answer': "It was used as a cyanide storage facility and later declared as the 'Republic of Poetry'"}, {'question': 'When was the Maiden’s Tower reopened to visitors after restoration?', 'answer': 'On Thursday, May 11th, 2023'}, {'question': 'How often are boat trips to the Maiden’s Tower available, and from which piers?', 'answer': 'Boat trips are available daily between 09:30 and 20:00 at 90-minute intervals from Karaköy and Üskü ...
# {'questions': [{'question': 'In which year were the mosaics in the northeastern section of the cloister in Eastern Roman Grand Palace unearthed?', 'answer': '1935'}, {'question': 'What is the date range of the works exhibited in the Great Palace Mosaics Museum?', 'answer': '450-550 AD'}, {'question': 'Do the mosaics in the Great Palace Mosaics Museum have religious content?', 'answer': 'No'}, {'question': 'What types of scenes are depicted in the mosaics of the Great Palace Mosaics Museum?', 'answer': 'Scenes from daily life, nature, and mythology'}, {'question': 'Where is the Great Palace Mosaics Museum located?', 'answer': 'Inside the Arasta Market in the Blue Mosque Complex'}, {'question': 'How much of the mosaic area was uncovered in the Great Palace Mosaics Museum?', 'answer': '180 square meters'}, {'question': 'Under whose management was the Great Palace Mosaics Museum in 1953?', 'answer': 'İstanbul Archaeology Museum'}, {'question': 'As of 1979, which museum became the unit under which the Great Palace Mosaics Museum operated?', 'answer': 'Hagia Sophia Museum'}, {'question': 'When did the restoration and conservation of the mosaics begin and end?', 'answer': '1982 to 1997'}, {'question': 'What institution collaborated with the General Directorate of Monuments and Museums for the restoration and conservation of the mosaics?', 'answer': 'Austrian Academy of Sciences'}, {'question': 'What materials are the mosaic grains made of, and what is their average size?', 'answer': 'Limestone, terracotta, and colored stones with an average size of 5mm'}, {'question': 'What styles and techniques are used in the mosaics of the Great Palace Mosaics Museum?', 'answer': 'Opus Vermiculite style and Fishscale technique'}, {'question': 'What is one of the most outstanding mosaics in the museum and what does it depict?', 'answer': 'A scene of a lizard eating a griffon'}, {'question': 'How many human and animal figures and themes are depicted on the mosaics?', 'answer': '150 human and animal figures and 90 different themes'}, {'question': 'Who built the Blue Mosque and in which century?', 'answer': 'Sedefkar Mehmet Aga, one of the students of Sinan the Architect, in the 17th century'}, {'question': 'Why is the Blue Mosque known by its common name?', 'answer': 'Because there are 21 thousand 43 eye-catching Iznik tiles on its walls to the second window'}, {'question': 'How many minaret balconies does the Blue Mosque have, and why?', 'answer': '14 minaret balconies, because Sultan Ahmed I is the 14th Sultan'}, {'question': "What is the significance of Sultan Ahmed I's tomb in relation to the Blue Mosque?", 'answer': 'It is adjacent to the mosque garden'}, {'question': 'What are the summer and winter opening hours of the Great Palace Mosaics Museum?', 'answer': 'Summer (1 April to 1 October): 09:00 to 19:00, Winter (1 October to 1 April): 09:00 to 18:30'}, {'question': 'What time does the box office close at the Great Palace Mosaics Museum in the summer and winter?', 'answer': 'Summer: 18:30, Winter: 18:00'}, {'question': 'What is the ticket price for the Great Palace Mosaics Museum?', 'answer': '10€ (Euro)'}, {'question': 'Is the Great Palace Mosaics Museum currently open to visitors?', 'answer': 'No, it is currently closed for a restoration and enhancement project'}, {'question': 'What is the address of the Great Palace Mosaics Museum?', 'answer': 'Kabasakal Cad. Torun Sk. Arasta Çarşısı (Bazaar) No:86, 34122 Sultanahmet/Fatih/İstanbul'}]}
# {'questions': [{'question': 'In which district of Istanbul is the Adam Mickiewicz Museum located?', 'answer': 'Beyoğlu'}, {'question': 'Who operates the Adam Mickiewicz Museum?', 'answer': 'The Museum of Turkish and Islamic Arts'}, {'question': 'When was Adam Mickiewicz born?', 'answer': '24 December 1798'}, {'question': 'Where was Adam Mickiewicz born?', 'answer': 'Zaosie near Nowgrèdek'}, {'question': 'When did Adam Mickiewicz die?', 'answer': '26 November 1855'}, {'question': 'Where did Adam Mickiewicz die?', 'answer': 'İstanbul, in a rented house in the Kurtuluş district'}, {'question': 'What are the main professions of Adam Mickiewicz?', 'answer': 'Poet, drama writer, essayist, publicist, translator, political activist'}, {'question': 'What is Adam Mickiewicz known for in Polish literature?', 'answer': 'He is regarded as the greatest Romantic poet of Polish literature and is the author of the Polish national epic poem'}, {'question': 'What positions did Adam Mickiewicz hold?', 'answer': 'He worked as a teacher at the Kovno school, a lecturer at the Lausanne Academy and the Paris Collège de France, and the editor-in-chief of Polish newspapers published in exile'}, {'question': 'What did Adam Mickiewicz plan to do in 1855?', 'answer': 'He planned to organize Polish legions to fight Tsarist Russia during the Crimean War'}, {'question': 'Who did Adam Mickiewicz befriend in Istanbul?', 'answer': 'Michał Czajkowski (Sadık Paşa), who commanded the Polish forces there'}, {'question': 'What illness is believed to have caused Adam Mickiewicz’s death?', 'answer': 'Cholera, which he is believed to have caught while visiting patients in tents in the Kurtuluş district'}, {'question': 'What was the address of the house where Adam Mickiewicz lived in Istanbul?', 'answer': 'The house was located at the junction of Yeni Şehir and Kalyoncu Kulluk, rented from Mrs. Rudnicka'}, {'question': 'What significant event happened in March 1870 in the Pera district?', 'answer': 'A massive fire destroyed most of the Pera district, including the building where Mickiewicz stayed during his final days and passed away'}, {'question': 'Who bought the plot and reconstructed the building after the 1870 fire?', 'answer': 'Jόsef Ratyński'}, {'question': 'What is the current address of the Adam Mickiewicz Museum?', 'answer': 'Bostan Mah. Tatlı Badem Sk. No:17, 34435 Beyoğlu/İstanbul'}, {'question': 'What was the condition of the room where Adam Mickiewicz lived in his final days?', 'answer': 'It was simple and modest, with a table, several simple chairs, and a bed covered with a straw mattress and a Turkish rug, placed in the corner. The room was dark and damp'}, {'question': 'When did the museum open to the public?', 'answer': '1955, on the 100th anniversary of Mickiewicz’s death'}, {'question': 'What is housed in the basement of the Adam Mickiewicz Museum?', 'answer': 'The crypt where Mickiewicz was temporarily buried for one month'}, {'question': 'What does the museum contain?', 'answer': 'Mickiewicz’s manuscripts, historical documents, and paintings'}, {'question': 'What are the summer hours of the Adam Mickiewicz Museum?', 'answer': '09:00 to 19:30'}, {'question': 'What are the winter hours of the Adam Mickiewicz Museum?', 'answer': '09:00 to 17:00'}, {'question': 'Is there an entry fee to visit the Adam Mickiewicz Museum?', 'answer': 'No, entry is free'}, {'question': 'Is the Adam Mickiewicz Museum open every day?', 'answer': 'Yes, it is open every day'}]}
# {'questions': [{'question': 'In which neighborhood of Istanbul are the Istanbul Archaeology Museums located?', 'answer': 'The Sultanahmet neighborhood.'}, {'question': 'How many major sections does the Istanbul Archaeology Museums consist of?', 'answer': 'Three major sections: The Archaeology Museum, The Museum of the Ancient Orient, and The Tiled Kiosk Museum.'}, {'question': 'Who was the museum director and master painter during the late 19th century responsible for forming the palace collections of the Istanbul Archaeology Museums?', 'answer': 'Osman Hamdi Bey.'}, {'question': 'In what year did the institutional emergence of museums in the Ottoman Empire and Turkey begin?', 'answer': '1869, with the establishment of the Istanbul Archaeological Museums as Müze-i Hümayun.'}, {'question': 'Where were the archaeological works initially housed when the Istanbul Archaeological Museums were established?', 'answer': 'In the Hagia Irene Church.'}, {'question': 'Why was the Tiled Kiosk converted into a museum?', 'answer': 'Due to the insufficiency of Hagia Irene.'}, {'question': 'In what year did the Tiled Kiosk, after restoration, open its doors as a museum?', 'answer': '1880.'}, {'question': 'What significant breakthrough in Turkish museology occurred in 1881?', 'answer': 'Osman Hamdi Bey was assigned as the museum director.'}, {'question': 'Which famous sarcophagus did Osman Hamdi Bey bring back to Istanbul from his excavations in Sidon between 1887 and 1888?', 'answer': 'The Alexander the Great sarcophagus.'}, {'question': 'When was the Tiled Kiosk, the oldest building in the Istanbul Archaeological Museum complex, built?', 'answer': '1472 CE.'}, {'question': 'What is the original name of the Tiled Kiosk in Turkish?', 'answer': 'Sırça Köşk.'}, {'question': 'Which architect is attributed to the design of the Tiled Kiosk?', 'answer': 'An unknown Persian architect.'}, {'question': 'What does the entrance of the Tiled Kiosk feature?', 'answer': 'A 14-column marble arcade decorated with mosaic tiles.'}, {'question': 'What was the initial purpose of the building that later became the Museum of the Ancient Orient?', 'answer': 'It was initially established as the first academy of fine arts of the Ottoman Empire.'}, {'question': 'Who designed the Istanbul Archaeological Museums’ Classical Building?', 'answer': 'Alexander Vallaury.'}, {'question': 'When was the Classical Building of the Istanbul Archaeological Museums opened?', 'answer': 'June 13th, 1891.'}, {'question': 'What are the summer period opening hours of the Istanbul Archaeology Museum?', 'answer': '09:00–21:00.'}, {'question': 'What are the winter period opening hours of the Istanbul Archaeology Museum?', 'answer': '09:00–18:30.'}, {'question': 'What is the cost of a ticket to the Istanbul Archaeology Museum?', 'answer': '15€ (Euro).'}, {'question': 'What is the name of the audio guide service available at the Istanbul Archaeology Museum?', 'answer': 'Voice of Museum.'}, {'question': 'In which part of Istanbul is the Istanbul Archaeology Museum complex located?', 'answer': 'The Sultanahmet neighborhood, in the historical peninsula of the Fatih district, on the Osman Hamdi Bey slope, which connects Gülhane Park with the Topkapı Palace Museum.'}, {'question': 'What is the address of the Istanbul Archaeology Museum?', 'answer': 'Alemdar Cad. Osman Hamdi Bey Yokuşu Sk. 34122 Gülhane/Fatih/İSTANBUL.'}]}
# {'questions': [{'question': 'What is the Galata Mevlevi House Museum also known as?', 'answer': 'Mevlevihanesi, Galata Mevlevi Lodge, Kulekapısı Mevlevi Lodge, or Galip Dede Tekke.'}, {'question': 'When was the Galata Mevlevi House Museum established?', 'answer': '1491'}, {'question': 'What was the museum originally known as before 2011?', 'answer': 'Divan Literature Museum'}, {'question': 'In what year was the museum reorganized as the Galata Mevlevi Lodge Museum?', 'answer': '2011'}, {'question': 'What features can be found in the Sema area on the ground floor of the museum?', 'answer': 'A walnut-covered floor, a mihrap (prayer niche), and a minber (pulpit)'}, {'question': 'What is written on the calligraphy panel in the Mıtrıb Mahfili?', 'answer': 'Ya Hazrat-e Mawlana'}, {'question': 'Who is the calligraphy panel in the Mıtrıb Mahfili attributed to?', 'answer': 'Yesarizade Mustafa İzzet'}, {'question': 'What exhibitions are featured on the upper level of the museum?', 'answer': 'Mustafa Düzgünman’s Marbling Exhibition, the Calligraphy Exhibition, the Hilye-i Şerif Sheets Exhibition, the Çelebi Lodge, the Royal Lodge, and the Ottoman Army Band and Musical Instruments Exhibition'}, {'question': 'When was the Tomb of Sheikh Galip built?', 'answer': '1819'}, {'question': 'Who are some of the notable figures buried in the Tomb of Sheikh Galip?', 'answer': 'İsmail Ankaravi (d. 1731), İsa Dede (d. 1771), Selim Dede (d. 1777), Galip Dede (d. 1799), and Mehmed Ruhi Dede (d. 1810)'}, {'question': 'When was the Tomb of Halet Efendi built?', 'answer': '1872'}, {'question': 'Who are some of the notable figures buried in the Tomb of Halet Efendi?', 'answer': 'Halet Efendi, Kudretullah Dede, Ataullah Dede, Ubeydullah Dede, and Emine Hanım'}, {'question': 'What is the schedule for the whirling dervish ceremonies at the museum?', 'answer': 'Every Sunday at 6 PM, lasting for 1 hour'}, {'question': 'How much do tickets for the whirling dervish ceremonies cost?', 'answer': '30.00 ₺'}, {'question': 'Where can tickets for the whirling dervish ceremonies be booked?', 'answer': 'Online at https://biletinial.com/'}, {'question': 'How many seats are available for the whirling dervish ceremonies?', 'answer': '150'}, {'question': 'Where is the Hodja Pasha Culture Center located?', 'answer': 'Near Sirkeci tram station T1 (Tram 1)'}, {'question': 'What is the ticket price for the Galata Mevlevi House Museum?', 'answer': '7€ (Euro)'}, {'question': 'What are the summer operating hours for the museum?', 'answer': '09:00 to 20:00 from 1 April to 1 October'}, {'question': 'What are the winter operating hours for the museum?', 'answer': '09:00 to 18:30 from 1 October to 1 April'}, {'question': 'When does the box office close during summer?', 'answer': '19:00'}, {'question': 'When does the box office close during winter?', 'answer': '17:30'}, {'question': 'On which day is the museum closed?', 'answer': 'Mondays'}, {'question': 'What is the address of the Galata Mevlevi House Museum?', 'answer': 'Şahkulu Mh. Galip Dede Cad. No:15, 34420 Beyoğlu/İstanbul'}]}
# {'questions': [{'question': 'When was the History of Islamic Science and Technology Museum opened?', 'answer': '2008'}, {'question': 'Who prepared the concept for the History of Islamic Science and Technology Museum?', 'answer': 'Prof. Dr. Fuat Sezgin'}, {'question': 'What time period do the exhibits in the museum cover?', 'answer': 'Between the 9th and 16th centuries'}, {'question': 'How many sections does the museum consist of?', 'answer': '12 sections'}, {'question': 'What is one of the highlights of the museum?', 'answer': 'The Elephant Clock'}, {'question': 'Who designed The Elephant Clock?', 'answer': 'Al-Jazari'}, {'question': 'What is al-Jazari considered to be the first scientist in?', 'answer': 'Cybernetics and robotics'}, {'question': 'What does The Elephant Clock demonstrate admiration for?', 'answer': 'The universality of Islam that spread from Spain to Central Asia'}, {'question': 'Where is The Elephant Clock located within the museum?', 'answer': 'In the Entrance Hall'}, {'question': 'What can visitors view in the Astronomy Section of the museum?', 'answer': 'Miniatures of important observatories from the Islamic Period, astrolabes, world globes, and measuring instruments'}, {'question': 'What types of clocks are displayed in the Clock and Marine Section?', 'answer': 'Sun dials, clocks designed by al-Jazari and al-Biruni, mechanical clocks by Taqi al-Din, a chandelier clock, the Andalusian candle clock with twelve doors'}, {'question': 'What book does the Physics Section showcase tools and devices from?', 'answer': 'Kitabü’l-Hıyel by al-Jazari'}, {'question': 'What tool by al-Biruni is notable in the Physics Section?', 'answer': 'A pycnometer to determine specific gravity'}, {'question': 'What is one of the notable displays in the Physics Section related to pumping?', 'answer': 'A helical pump'}, {'question': 'What is the operating hours of the museum during summer?', 'answer': '09:00 to 19:00'}, {'question': 'What is the operating hours of the museum during winter?', 'answer': '09:00 to 18:30'}, {'question': 'When does the box office close during summer hours?', 'answer': '18:30'}, {'question': 'When does the box office close during winter hours?', 'answer': '17:30'}, {'question': 'Is the museum open every day?', 'answer': 'Yes'}, {'question': 'Where is the museum located?', 'answer': 'Cankurtaran, Taya Hatun Sk. Gülhane Parkı, 34122 Fatih/İstanbul'}, {'question': 'What is the ticket price for the museum?', 'answer': '10€ (Euro)'}]}
# {'questions': [{'question': 'When did Topkapı Palace serve as the main residence and administrative headquarters of the Ottoman sultans?', 'answer': 'Between the 15th and 19th centuries'}, {'question': 'Who built Topkapı Palace and when?', 'answer': 'Mehmet the Conqueror shortly after the Conquest of Constantinople in 1453'}, {'question': 'What are some of the main features of Topkapı Palace that visitors can see?', 'answer': 'Opulent pavilions, a jewel-filled Treasury, and the sprawling Harem'}, {'question': 'What is the First Court of Topkapı Palace also known as?', 'answer': 'The Court of the Janissaries'}, {'question': 'What monuments are located in the First Court of Topkapı Palace?', 'answer': 'Hagia Irene Museum and the Imperial Mint'}, {'question': 'What can visitors see in the Second Court of Topkapı Palace?', 'answer': 'The Palace Kitchens, the ornate Imperial Council Chamber, and the Outer Treasury exhibiting Ottoman and European arms and armor'}, {'question': 'What was the function of the Harem in Topkapı Palace?', 'answer': 'It served as the imperial family quarters, where concubines were schooled in Turkish culture, Islam, music, and dance'}, {'question': 'What are some of the notable areas within the Harem?', 'answer': 'The Apartments of the Valide Sultan, the Courtyard of the Concubines, and the gilded Privy Chamber of Murat III'}, {'question': 'How is the Third Court of Topkapı Palace accessed?', 'answer': 'Through the Gate of Felicity'}, {'question': 'What notable rooms are in the Third Court of Topkapı Palace?', 'answer': 'The Audience Chamber, the Library of Ahmet III, and the Sacred Safekeeping Rooms'}, {'question': 'What famous items are displayed in the Imperial Treasury of Topkapı Palace?', 'answer': 'Stunning collections of jewels such as the famous Topkapı Dagger and the Spoonmaker’s Diamond'}, {'question': 'What can be found in the Fourth Court of Topkapı Palace?', 'answer': 'Pleasure pavilions, including the Mecidiye Kiosk and the Tulip Garden'}, {'question': 'What are some architectural masterpieces in the Fourth Court of Topkapı Palace?', 'answer': 'The Baghdad Kiosk, the Circumcision Room, and the Marble Terrace adorned with pools and gardens'}, {'question': 'How much does the combined ticket for Topkapı Palace, Harem, and Hagia Irene cost?', 'answer': '1700 ₺'}, {'question': 'What are the operating hours of Topkapı Palace during summer?', 'answer': '09:00 to 18:00'}, {'question': 'What are the operating hours of Topkapı Palace during winter?', 'answer': '09:00 to 18:00'}, {'question': 'When does the box office close at Topkapı Palace?', 'answer': '17:30'}, {'question': 'On which day is Topkapı Palace closed?', 'answer': 'Tuesdays'}, {'question': 'What is the address of Topkapı Palace?', 'answer': 'Cankurtaran Mah. Babı Hümayun Cad. No:1, 34122 Sultanahmet/Fatih/İstanbul'}, {'question': 'How can visitors reach Topkapı Palace?', 'answer': 'Via the T1 tram line, a short walk from Sultanahmet or Gulhane tram stations'}, {'question': 'Are there any discounts or free admissions at Topkapı Palace?', 'answer': 'Discounted tickets for foreign students aged 12–24 with an ISIC card, free admission for children under six, Turkish citizens under 18, and disabled visitors with one companion'}, {'question': 'What advice is given to visitors to Topkapı Palace?', 'answer': 'Arrive early due to long queues at security checkpoints and consider guided tours or audio guides for detailed insights into the palace’s rich history'}, {'question': 'Are photography and smoking allowed inside Topkapı Palace?', 'answer': 'Photography inside the museum halls is prohibited, and smoking is strictly forbidden throughout the premises'}, {'question': 'What types of items are on display at Topkapı Palace?', 'answer': 'Vast collections of porcelain, robes, weapons, Ottoman miniatures, Islamic calligraphic manuscripts, and treasures'}]}
# {'questions': [{'question': 'What are the summer operational hours for the Rumeli Fortress Museum?', 'answer': 'The museum is open from 09:00 to 19:00 with the box office closing at 18:00.'}, {'question': 'What are the winter operational hours for the Rumeli Fortress Museum?', 'answer': 'The museum is open from 09:00 to 17:00 with the box office closing at 16:00.'}, {'question': 'On which day of the week is the museum closed?', 'answer': 'Monday'}, {'question': 'What is the address of the Rumeli Fortress Museum?', 'answer': 'Rumeli Hisarı, Yahya Kemal Cad. No:42 34470 Sarıyer/İSTANBUL'}, {'question': 'What is the ticket price for the Rumeli Fortress Museum?', 'answer': '6€ (Euro)'}, {'question': 'What historical structures are included in the Fortresses Museum?', 'answer': 'Rumeli Fortress, Yedikule Fortress, and Anadolu Fortress.'}, {'question': "What is the meaning of the name 'Rumeli Hisarı'?", 'answer': 'Fortress on the Land of the Romans'}, {'question': 'When was the Rumeli Fortress built?', 'answer': '1452'}, {'question': 'Who ordered the construction of the Rumeli Fortress?', 'answer': 'Sultan Mehmet the Conqueror'}, {'question': 'What was the primary purpose of building the Rumeli Fortress?', 'answer': 'To manage passing ships in the Bosphorus, create a military-financial control point, and prevent attacks from the north of the Bosphorus'}, {'question': 'How long did it take to build the Rumeli Fortress?', 'answer': 'Four months'}, {'question': 'Who was the architect of the Rumeli Fortress?', 'answer': 'Muslihiddin Ağa'}, {'question': 'What was the role of Firuz Bey in the Rumeli Fortress?', 'answer': 'Firuz Bey was appointed as the commander of the few soldiers in the fortress with the authority to control ships passing the Bosphorus.'}, {'question': 'What happened to the Bosphorus naval traffic after the construction of the Rumeli Fortress?', 'answer': 'Bosphorus naval traffic was effectively cut off in 1453.'}, {'question': 'What happened to the Rumeli Fortress after the conquest of Istanbul?', 'answer': 'It lost its strategic importance and became an imperial prison and customs checkpoint.'}, {'question': 'What significant event damaged the Rumeli Fortress?', 'answer': 'An earthquake in 1509 and a fire in the 17th century.'}, {'question': 'When was the last major maintenance work done on the Rumeli Fortress?', 'answer': 'During the reign of Selim III (1789-1807)'}, {'question': 'What is the significance of the Rumeli Fortress Museum and its towers?', 'answer': 'They are among the largest surviving fortification structures in the world.'}, {'question': 'What is the historical name of the Anadolu Fortress?', 'answer': 'It was built by Sultan I. Beyazıt in 1394 and is located in the narrowest part of the Bosphorus.'}, {'question': 'How was the Rumeli Fortress used in terms of military technology?', 'answer': 'It was used as a testing area to develop state-of-the-art cannon technology.'}, {'question': 'Where is one of the cannons from the Rumeli Fortress currently on display?', 'answer': 'Fort Nelson’s royal armouries museum near the city of Portsmouth, England'}, {'question': 'When was the 17-ton cannon gifted to the Queen by Sultan Abdulaziz?', 'answer': '1868'}, {'question': 'What historical inscriptions are on the muzzle of the 17-ton cannon?', 'answer': 'Help O God. The Sultan Muhammad Khan, son of Murad. The work of Munir Ali in the month of Rajab. In the year 868 (A.D. 1464).'}, {'question': 'What are some alternative names for the Rumeli Fortress?', 'answer': 'Kal’a-i Cedid, Kulle-i Cedide, Yenicehisar, Yenihisar, Bogazkesen Kalesi, Bogazkesen Hisarı, Nikhisar (Guzelhisar), Baskesen Hisarı'}, {'question': 'Where was the timber and stones for the Rumeli Fortress brought from?', 'answer': 'Timber was brought from Izmit and Karadeniz Ereglisi, and stones were brought from various parts of Anatolia and spolies from ruined Byzantine structures in the surrounding area.'}, {'question': 'When was the Rumeli Fortress Mu ...
# {'questions': [{'question': 'When did the İstanbul Airport Museum open?', 'answer': '17th of July 2020'}, {'question': 'What is the name of the exhibition currently on display at the İstanbul Airport Museum?', 'answer': '‘Treasures of Türkiye: Faces of the Throne’'}, {'question': 'How many items are displayed in the ‘Treasures of Türkiye: Faces of the Throne’ exhibition?', 'answer': '316'}, {'question': 'How many museums in Türkiye contributed items to the ‘Treasures of Türkiye: Faces of the Throne’ exhibition?', 'answer': '29'}, {'question': 'What significant artefact is included in the ‘Treasures of Türkiye: Faces of the Throne’ exhibition?', 'answer': 'The ‘Kadesh Treaty’'}, {'question': 'What is the objective of the ‘Treasures of Türkiye: Faces of the Throne’ exhibition?', 'answer': 'To display twelve thousand years of Anatolian history through the concept of ‘Rule and Ruler’'}, {'question': 'How many square meters does the İstanbul Airport Museum cover?', 'answer': '1000m²'}, {'question': 'On which floor of the airport is the İstanbul Airport Museum located?', 'answer': 'International departures floor'}, {'question': 'How often does the İstanbul Airport Museum plan to change its exhibition?', 'answer': 'Every year'}, {'question': 'What periods are represented in the artefacts displayed in the İstanbul Airport Museum’s first exhibition?', 'answer': 'Prehistoric, Hittite, Urartu, Phyrgian, Lydian, Roman, Byzantine, Seljuk, Ottoman, and modern Turkish periods'}, {'question': 'What are the opening hours of the İstanbul Airport Museum in the summer period?', 'answer': '08:30 to 23:00'}, {'question': 'What are the opening hours of the İstanbul Airport Museum in the winter period?', 'answer': '08:30 to 23:00'}, {'question': 'What time does the box office close in the summer period?', 'answer': '22:00'}, {'question': 'What time does the box office close in the winter period?', 'answer': '22:30'}, {'question': 'Is the İstanbul Airport Museum open every day?', 'answer': 'Yes'}, {'question': 'What is the ticket price for the İstanbul Airport Museum?', 'answer': '13€'}, {'question': 'Are museum passes valid for the İstanbul Airport Museum?', 'answer': 'No'}, {'question': 'Are children under 8 years old admitted free to the İstanbul Airport Museum?', 'answer': 'Yes'}, {'question': 'What is the address of the İstanbul Airport Museum?', 'answer': 'Tayakadın, İstanbul Yeni Havalimanı, Terminal Cad. 34283 Arnavutköy/İstanbul'}, {'question': 'What is the email address of the İstanbul Airport Museum?', 'answer': 'istanbularkeoloji@ktb.gov.tr'}, {'question': 'What are the phone numbers of the İstanbul Airport Museum?', 'answer': 'Phone 1: +90(212)5207740, Phone 2: +90(212)5207741'}, {'question': 'What is the fax number of the İstanbul Airport Museum?', 'answer': 'Fax: +90(212)5274300'}]}
# {'questions': [{'question': 'What are the summer opening and closing hours for Hagia Irene?', 'answer': 'Opening time: 09:00, Closing time: 18:00'}, {'question': 'What are the winter opening and closing hours for Hagia Irene?', 'answer': 'Opening time: 09:00, Closing time: 18:00'}, {'question': 'When does the box office close during the summer period?', 'answer': '17:30'}, {'question': 'When does the box office close during the winter period?', 'answer': '17:30'}, {'question': 'On which day is Hagia Irene closed?', 'answer': 'Tuesday'}, {'question': 'What is the address of Hagia Irene?', 'answer': 'Cankurtaran, Topkapı Sarayı, No:1, 34122 Fatih/İstanbul'}, {'question': 'What is the ticket price for Hagia Irene?', 'answer': '600 ₺'}, {'question': 'How long are Hagia Irene tickets valid for?', 'answer': '1 day from the date of purchase'}, {'question': "What does the name 'Hagia Irene' mean?", 'answer': 'Sacred peace'}, {'question': 'In which year was Hagia Irene originally built?', 'answer': '330'}, {'question': 'Who was the emperor during the Nika Revolt in 532?', 'answer': 'Emperor Justinianus'}, {'question': 'What significant event happened to Hagia Irene in 532?', 'answer': 'It was devastated during the Nika Revolt'}, {'question': 'Who rebuilt Hagia Irene after the Nika Revolt?', 'answer': 'Emperor Justinianus'}, {'question': 'What is the architectural plan of Hagia Irene?', 'answer': 'A domed church with a basilical plan'}, {'question': 'What is the structure of Hagia Irene in terms of its sections?', 'answer': 'It consists of three sections: naos, narthex, and atrium'}, {'question': 'What was the impact of the great earthquake of 740 on Hagia Irene?', 'answer': 'It caused damages to the church'}, {'question': 'Which emperors repaired Hagia Irene after the great earthquake of 740?', 'answer': 'Leo III and Constantine Copronymus'}, {'question': 'What was the purpose of the cross depiction on the half dome of Hagia Irene?', 'answer': 'It was made during the Iconoclastic era'}, {'question': 'What was the use of Hagia Irene after the fall of Constantinople?', 'answer': 'It was used as a loot and gun depot (Harbiye Warehouse)'}, {'question': 'Who added the entry portico to Hagia Irene?', 'answer': 'Sultan Ahmet III'}, {'question': 'When were the marble inscription tablets restored?', 'answer': 'One in 1726 and one in 1744'}, {'question': 'What was the name of the weapons depot in the 19th century?', 'answer': 'Harbiye Ambarı (war academy depot)'}, {'question': 'When did Hagia Irene become the first official museum of the country?', 'answer': '1869'}, {'question': 'What was the name of the first official museum in Hagia Irene?', 'answer': 'Müze-i Hümayun (Imperial Museum)'}, {'question': 'Between which years did Hagia Irene serve as the first Military Museum?', 'answer': '1908 and 1940'}]}
# {'questions': [{'question': 'What is the current ticket price for Fethiye (Pammakaristos Church) Mosque/Museum?', 'answer': '3€ (Euro)'}, {'question': 'What is the current state of Fethiye (Pammakaristos Church) Mosque/Museum?', 'answer': 'Closed'}, {'question': 'What was the original name of the Fethiye Mosque?', 'answer': 'Monastery of the Theotokos Pammakaristos (Mother of God the All-Blessed)'}, {'question': 'On which hill of Constantinople was the Monastery of the Theotokos Pammakaristos located?', 'answer': 'The fifth hill'}, {'question': 'In which modern Istanbul neighborhood is the Fethiye Mosque located?', 'answer': 'Çarsamba'}, {'question': 'Which churches are located near the Fethiye Mosque?', 'answer': 'Chora and Blachernai churches'}, {'question': 'When was the Fethiye Mosque originally founded?', 'answer': 'During the Komnenian era, with late Byzantine additions'}, {'question': 'Who are the founders of the Monastery of the Theotokos Pammakaristos?', 'answer': 'John Komnenos and his wife, Anna Doukaina'}, {'question': 'What significant restoration was done to the church after 1261?', 'answer': 'It was extensively restored by Michael Tarchaneiotes Glabas'}, {'question': 'What did Maria, the widow of Michael Tarchaneiotes Glabas, build as a funerary chapel?', 'answer': 'A four-columned parekklesion with a two-storied narthex'}, {'question': 'Who was the abbot of the monastery that was elected as patriarch in 1294?', 'answer': 'Kosmas, who became John XII'}, {'question': 'What is the architectural type of the katholikon of Pammakaristos?', 'answer': 'An ambulatory type of the cross-domed church'}, {'question': 'When was the north ambulatory of the Pammakaristos church constructed?', 'answer': 'In the late thirteenth century'}, {'question': 'How many arcosolia were found in the northern arm of the ambulatory of Pammakaristos?', 'answer': 'Four'}, {'question': 'What is the size and structure of the cistern under the apse and nave of the church?', 'answer': 'It is 7 x 3 meters and has 12 columns with Corinthian capitals'}, {'question': 'When was the church made the seat of the Patriarchate?', 'answer': 'From around 1455 to 1587, by Gennadios II Scholarios'}, {'question': 'What significant alteration occurred to the church in 1587?', 'answer': 'It was converted into a mosque, called Fethiye Mosque'}, {'question': 'During whose reign was the church converted into a mosque?', 'answer': 'During the reign of Murad III'}, {'question': 'What was the name of the mosque after its conversion in 1587?', 'answer': 'Fethiye Mosque'}, {'question': 'What was the Fethiye Mosque named in commemoration of?', 'answer': 'The Ottoman conquest of Georgia'}, {'question': 'Who established the madrasa of Fethiye Mosque?', 'answer': 'Sinan Pasha, then the Grand Vizier'}, {'question': 'What significant alterations were made when the church was converted into a mosque?', 'answer': 'Replacement of the tripartite bema with a qibla wall, columns replaced with arches, and a minaret was added'}, {'question': 'When was the Fethiye Mosque significantly restored following a fire?', 'answer': 'In 1640'}, {'question': 'During whose reign was the Fethiye Mosque restored around 1845?', 'answer': 'During the reign of Sultan Abdulmecid'}, {'question': 'When did the Byzantine Institute in İstanbul begin to uncover the mosaics of the parekklesion?', 'answer': 'In 1950'}, {'question': 'When did the parekklesion of Fethiye Mosque become a museum?', 'answer': 'During the restorations of 1938-1940'}]}
# All questions saved to questions.json

# %%
with open("questions.json", "r") as f:
    questions = json.load(f)
    i = 0
    for q in questions:
        i += 1

print(i)
# Out:
# 390

# %%
from openai import OpenAI
import json

# Create OpenAI client
openai = OpenAI(
    api_key="API_KEY",
    base_url="https://api.deepinfra.com/v1/openai",
)

def generate_qa_istanbul_wiki(content, model="Qwen/Qwen2.5-72B-Instruct"):
    prompt = f""" 
        Analyze the following content about Istanbul and generate a diverse set of question-answer pairs strictly based on the provided text. 
        Content:
        {content}

        Instructions:
        1. Write clear, self-contained questions that can stand alone without referring back to the content. 
        2. The questions should focus on key facts, events, locations, dates, cultural elements, and historical context directly mentioned in the text.
        3. Ensure a mix of short factual questions (e.g., "What is the capital of Turkey?") and more detailed ones (e.g., "What role did the Hagia Sophia play in the history of Istanbul and the Byzantine Empire?").
        4. For longer questions, include context, comparisons, or explanations that require a detailed answer (e.g., "What are the main architectural features of the Hagia Sophia, and how did they influence later structures in Istanbul?").
        5. If the content lacks sufficient details, generate fewer but meaningful questions, keeping the answers concise and informative.
        6. Avoid vague or overly generic questions like "What is mentioned in the text?" or those requiring external knowledge.
        7. Prioritize factual, informative, and educational content, ensuring that each question has a clear, unambiguous answer. 
        8. The output should be formatted as a Python list of dictionaries in JSON format, with each dictionary containing:
            - "content": the excerpt or context used to generate the question
            - "question": the formulated question
            - "answer": the corresponding answer

        Example Output:
        {{"questions":[
            {{"content": "Used content to create this question","question": "When was Hagia Sophia built?", "answer": "537 AD"}},
            {{"content": "Used content to create this question","question": "What was the original purpose of Hagia Sophia?", "answer": "A church."}},
            {{"content": "Used content to create this question","question": "How did the Hagia Sophia influence the architecture of later mosques?", "answer": "Its large dome and innovative structural design inspired Ottoman mosque architecture."}}
        ]}}
    """

    # API call to OpenAI
    response = openai.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        response_format={ "type": "json_object" }
    )

    # Extract the generated content
    result = response.choices[0].message.content
    result = json.loads(result)
    # Return the JSON output as Python objects
    return result

# %%
# Open the JSON file containing museum data
with open("istanbul_places_documents.json", "r") as f:
    wiki_data = json.load(f)

# Create a list to store all questions
all_questions_wiki = []

# Loop through each museum
for museum in wiki_data[141:]:
    content = museum["text"]
    
    # Generate questions for each museum (assuming the function returns a list of dictionaries)
    questions = generate_qa_istanbul_wiki(content)
    # Change the word 'questions' to "questions" to match the required format in the questions content







    
    print(questions)
    questions = questions.get('questions')
    # Format each question into the required structure
    for q in questions:
        if type(q) != dict:
            break
        all_questions_wiki.append({
            "content": q["content"],
            "question": q["question"],
            "answer": q["answer"]
        })


# Write all questions to a single JSON file
with open("wiki_questions.json", "w") as f:
    json.dump(all_questions_wiki, f, indent=4)  # Pretty-print with indentation

print("All questions saved to questions.json")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[89], line 13
#      10 content = museum["text"]
#      12 # Generate questions for each museum (assuming the function returns a list of dictionaries)
# ---> 13 questions = generate_qa_istanbul_wiki(content)
#      14 # Change the word 'questions' to "questions" to match the required format in the questions content
#      15 questions = str(questions).replace('\'questions\'', '"questions"')
#
# Cell In[60], line 38, in generate_qa_istanbul_wiki(content, model)
#      11 prompt = f"""
#      12     Analyze the following content about Istanbul and generate a diverse set of question-answer pairs strictly based on the provided text.
#      13     Content:
#    (...)
#      34     ]}}
#      35 """
#      37 # API call to OpenAI
# ---> 38 response = openai.chat.completions.create(
#      39     model=model,
#      40     messages=[{"role": "user", "content": prompt}],
#      41     response_format={ "type": "json_object" }
#      42 )
#      44 # Extract the generated content
#      45 result = response.choices[0].message.content
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/openai/resources/chat/completions.py:859, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     817 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     818 def create(
#     819     self,
#    (...)
#     856     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     857 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     858     validate_response_format(response_format)
# --> 859     return self._post(
#     860         "/chat/completions",
#     861         body=maybe_transform(
#     862             {
#     863                 "messages": messages,
#     864                 "model": model,
#     865                 "audio": audio,
#     866                 "frequency_penalty": frequency_penalty,
#     867                 "function_call": function_call,
#     868                 "functions": functions,
#     869                 "logit_bias": logit_bias,
#     870                 "logprobs": logprobs,
#     871                 "max_completion_tokens": max_completion_tokens,
#     872                 "max_tokens": max_tokens,
#     873                 "metadata": metadata,
#     874                 "modalities": modalities,
#     875                 "n": n,
#     876                 "parallel_tool_calls": parallel_tool_calls,
#     877                 "prediction": prediction,
#     878                 "presence_penalty": presence_penalty,
#     879                 "reasoning_effort": reasoning_effort,
#     880                 "response_format": response_format,
#     881                 "seed": seed,
#     882                 "service_tier": service_tier,
#     883                 "stop": stop,
#     884                 "store": store,
#     885                 "stream": stream,
#     886                 "stream_options": stream_options,
#     887                 "temperature": temperature,
#     888                 "tool_choice": tool_choice,
#     889                 "tools": tools,
#     890                 "top_logprobs": top_logprobs,
#     891                 "top_p": top_p,
#     892                 "user": user,
#     893             },
#     894             completion_create_params.CompletionCreateParams,
#     895         ),
#     896         options=make_request_options(
#     897             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     898         ),
#     899         cast_to=ChatCompletion,
#     900         stream=stream or False,
#     901         stream_cls=Stream[ChatCompletionChunk],
#     902     )
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/openai/_base_client.py:1280, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1266 def post(
#    1267     self,
#    1268     path: str,
#    (...)
#    1275     stream_cls: type[_StreamT] | None = None,
#    1276 ) -> ResponseT | _StreamT:
#    1277     opts = FinalRequestOptions.construct(
#    1278         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1279     )
# -> 1280     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/openai/_base_client.py:957, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     954 else:
#     955     retries_taken = 0
# --> 957 return self._request(
#     958     cast_to=cast_to,
#     959     options=options,
#     960     stream=stream,
#     961     stream_cls=stream_cls,
#     962     retries_taken=retries_taken,
#     963 )
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/openai/_base_client.py:993, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     990 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     992 try:
# --> 993     response = self._client.send(
#     994         request,
#     995         stream=stream or self._should_stream_response_body(request=request),
#     996         **kwargs,
#     997     )
#     998 except httpx.TimeoutException as err:
#     999     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/ssl.py:1260, in SSLSocket.recv(self, buflen, flags)
#    1256     if flags != 0:
#    1257         raise ValueError(
#    1258             "non-zero flags not allowed in calls to recv() on %s" %
#    1259             self.__class__)
# -> 1260     return self.read(buflen)
#    1261 else:
#    1262     return super().recv(buflen, flags)
#
# File /opt/anaconda3/envs/deepl/lib/python3.9/ssl.py:1135, in SSLSocket.read(self, len, buffer)
#    1133         return self._sslobj.read(len, buffer)
#    1134     else:
# -> 1135         return self._sslobj.read(len)
#    1136 except SSLError as x:
#    1137     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
import json
all_questions_wiki = []

with open("temp_cleaned_wiki_questions.txt", "r") as f:
    i = 0  # Counter for valid lines
    j = 0  # Counter for total lines
    for line in f:
        j += 1
        if j > 11:
            try:
                line = str(line).replace('"', '\'')
                # Replace invalid characters and fix JSON formatting
                line = str(line).replace('\'questions\'', '"questions"')
                line = str(line).replace('\'content\'', '"content"')
                line = str(line).replace('\'question\'', '"question"')
                line = str(line).replace('\'answer\'', '"answer"')

                line = str(line).replace('"content": \'', '"content": "')
                line = str(line).replace('"question": \'', '"question": "')
                line = str(line).replace('"answer": \'', '"answer": "')
                
                line = str(line).replace('\', "answer"', '", "answer"')
                line = str(line).replace('\', "content"', '", "content"')
                line = str(line).replace('\', "question"', '", "question"')
                line = str(line).replace('\'}', '"}')
                line = str(line).replace('\\', '')
                # Attempt to parse JSON
                line = json.loads(line)
                i += 1  # Increment valid counter
                line
            except Exception as e:
                # Find and highlight the problematic part
                error_index = str(e).find("char")  # Locate error position
                if error_index != -1:
                    # Extract position from error message
                    start = str(e).find("(") + 1
                    end = str(e).find(")", start)
                    pos = int(str(e)[start:end].split()[1])  # Character position
                    # Print error context with problematic part
                    print(f"Error: {e}")
                    print(f"Errored part: {line[max(0, pos-20):pos+20]}")  # Show ±20 chars
                    print(f"Line number: {j}")

                else:
                    # If position not found, display the full error
                    print(f"Error: {e}")
                continue
        else:
            line = json.loads(line)
            i += 1

        questions = line["questions"]
        for q in questions:

            all_questions_wiki.append({
                "content": q["content"],
                "question": q["question"],
                "answer": q["answer"]
            }

        )
            
    print(f"Total lines processed: {j}")


# Write all questions to a single JSON file
with open("wiki_questions_2.json", "w") as f:
    json.dump(all_questions_wiki, f, indent=4)  # Pretty-print with indentation
            
print(f"Valid JSON lines processed: {i}")
# Out:
# Total lines processed: 141
# Valid JSON lines processed: 141

# %%
with open("combined_questions.json", "r") as f:
    questions = json.load(f)
    i = 0
    for q in questions:
        i += 1

print(i)
# Out:
# 3266

# %%
import json

# Load the two files
with open("wiki_questions.json", "r") as f1, open("wiki_questions_2.json", "r") as f2, open("questions.json", "r") as f3:
    data1 = json.load(f1)
    data2 = json.load(f2)
    data3 = json.load(f3)
    # Change museum column to content in data3
    for d in data3:
        d['content'] = d.pop('museum')

# Combine data
combined_data = data3 + data2 + data1 

# Save the combined file
with open("combined_questions.json", "w") as outfile:
    json.dump(combined_data, outfile, ensure_ascii=False, indent=4)

# %%
from datasets import Dataset, DatasetDict
import json

# Load your combined JSON file
with open("combined_questions.json", "r") as f:
    data = json.load(f)

# Convert to Dataset
dataset = Dataset.from_dict({
    "content": [item["content"] for item in data],
    "question": [item["question"] for item in data],
    "answer": [item["answer"] for item in data]
})

# Push the dataset to HuggingFace Hub
dataset.push_to_hub("BlackFear/dl_project_uncleaned")
# Out:
# Creating parquet from Arrow format: 100%|██████████| 4/4 [00:00<00:00, 598.97ba/s]
# Uploading the dataset shards: 100%|██████████| 1/1 [00:01<00:00,  1.51s/it]
# CommitInfo(commit_url='https://huggingface.co/datasets/BlackFear/dl_project_uncleaned/commit/3fddde8524bf55b2a8db77dcf8110b744e3b5546', commit_message='Upload dataset', commit_description='', oid='3fddde8524bf55b2a8db77dcf8110b744e3b5546', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/BlackFear/dl_project_uncleaned', endpoint='https://huggingface.co', repo_type='dataset', repo_id='BlackFear/dl_project_uncleaned'), pr_revision=None, pr_num=None)
